# %% [markdown]
# ## Training with a ```Session``` object

# %%
import sys
sys.path.append('/home/emastr/phd/')
from architecture.session import Session, egeofno_ver1, egeofno_ver2, \
    egeofno_ver3, egeofno_ver4, svdfno_ver1, svdfno_ver2, svdfno_ver3, svdfno_ver4

######### FIX MATRIX PLOTTING TAMALE #####
N_train = 20001

# %%
save_name = "svdfno_ver4"
net = svdfno_ver4()
session = Session(net, save_name=save_name)
session.train_nsteps(N_train)


save_name = "svdfno_ver3"
net = svdfno_ver3()
session = Session(net, save_name=save_name)
session.train_nsteps(N_train)


save_name = "svdfno_ver1"
net = svdfno_ver1()
session = Session(net, save_name=save_name)
session.train_nsteps(N_train)

save_name = "svdfno_ver2"
net = svdfno_ver2()
session = Session(net, save_name=save_name)
session.train_nsteps(N_train)
# Out:
# Warning: old skipnet had no scale parameter
# [W Copy.cpp:244] Warning: Casting complex values to real discards the imaginary part (function operator())
# Warning: old skipnet had no scale parameters = 2.46e-01, 68 iter/s, shape=256
# Warning: old skipnet had no scale parameters = 2.34e-01, 64 iter/s, shape=256
# Warning: old skipnet had no scale parameters = 2.34e-01, 67 iter/s, shape=256
# Step 14000. Train loss = 2.04e-01, test loss = 2.38e-01, 63 iter/s, shape=256

# %%
save_name = "fno_ver1"
net = egeofno_ver1()
session = Session(net, save_name=save_name)
session.train_nsteps(N_train)

save_name = "fno_ver2"
net = egeofno_ver2()
session = Session(net, save_name=save_name)
session.train_nsteps(N_train)

save_name = "fno_ver3"
net = egeofno_ver3()
session = Session(net, save_name=save_name)
session.train_nsteps(N_train)

save_name = "fno_ver4"
net = egeofno_ver4()
session = Session(net, save_name=save_name)
session.train_nsteps(N_train)
# Out:
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# Warning: old skipnet had no scale parameter
# WARNING: Fixed bug to allow change in dimension3.24e-01, 64 iter/s, shape=256
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# Warning: old skipnet had no scale parameter
# WARNING: Fixed bug to allow change in dimension1.76e-01, 64 iter/s, shape=256
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# WARNING: Fixed bug to allow change in dimension
# Warning: old skipnet had no scale parameter
# WARNING: Fixed bug to allow change in dimension1.75e-01, 64 iter/s, shape=256
# Warning: old skipnet had no scale parameter
# Step 20000. Train loss = 3.25e-01, test loss = 3.25e-01, 169 iter/s, shape=256
