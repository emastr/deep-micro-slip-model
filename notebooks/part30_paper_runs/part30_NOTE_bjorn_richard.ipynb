# %% [markdown]
# ## Björn Enquist - Richard Tsai
#
# * Presentera problemet
#     * Carney och Enquist
#     * HMM för Stokes flöde, inte Navier stokes
#     * Premisser:
#         * Många mikrolösare
#         * Behöver inte vara jättehög precision
#         * Accellerera lösaren med ML
#     * Ersätta mikrolösarna med ML
#         * Förberäkna med Adjoints
#         * Använd nätverket för adjoints
#         * FNO, equivariant.
#         * Normaliserat.
#     * Kvarvarande Problem:
#         * Hur generell är metoden - Vilka PDE kan man göra så med?
#         * Vad kan man säga om konvergens av HMM-lösningen
#         * Placering / skalning av mikroproblem
#
# * Nästa steg
#     * Maskinlärning för multiskalproblem (homogeniseringsproblem)
#     * Var tillämpas HMM för tidsoberoende problem som ger samma typ av kopplade struktur
#     * Använda HMM för att ta fram data
#         * Lära en homogenisering, men hur?
#     * Seamless HMM med fiber bundles?
#         * Geometrisk maskinlärning
#         * Användbar filosofi?
