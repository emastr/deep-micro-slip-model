# %% [markdown]
# ### TODO
#
#
#
# ##### RESULTS THAT ARE MISSING
# 2) Convergence of HMM (one plot)
#     * Error as function of HMM iterations
#     * Divergence from true HMM over iterations
# 3) Training statistics
#     * Loss as function of iterations (Training / Test)
#     * If possible - Multiple architectures
# 4) Computation time
#     * GMRES vs FNO vs total HMM time, decomposed.
#     * Possibly, non-precomputed GMRES
# 5) Micro Error, data
#     * Unraveled x-y coordinate plots of Riesz representor + error bars
#     * show micro domain on the side + quiver plot + x-y decomposition in red/blue
#     * Mark the parameterisation points.
# 6) HMM Error Single channel
#     * Profiles, x and y
# 7) HMM Error cylinder
#     * Profiles, radial and azimuthal
# * Slip coefficient
# * Try New geometry
#     * Flow across capillaries
#     * Import svg?
#
# ##### Illustrations that are missing
# 1) Generate example Fenics figure
#     * Low resolution solver
#     * High resolution solver
#     * Overlay with different color, plot velocity profiles
# 8) Illustration of the multi scale problem
#     * Full domain
#     * Mark $\Omega_0$, $\Omega_\epsilon$, $\Gamma_\epsilon$ and micro domains $\Omega_x$
#     * Make generic, not just a box. Allow $\Gamma_\epsilon$ to be curved.
#     * Show the evaluation line in the micro domain
