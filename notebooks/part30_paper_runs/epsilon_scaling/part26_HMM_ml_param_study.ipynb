# %% [markdown]
# ## Stokes Flow in Periodic Channel with Robin boundary.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "none"#"last_expr_or_assign"

import numpy as np
import matplotlib.pyplot as plt
from util.logger import EventTracker
from util.basis_scaled import *
from util.plot_tools import *
from boundary_solvers.gauss_grid_2d import StokesDirichletProblem
from scipy.io import loadmat
import matplotlib.pyplot as plt
from util.interp import PiecewiseInterp2D
from hmm.stokes import *
from itertools import product
from hmm.stokes_deep import DeepMicroSolver, get_net
import matplotlib
import torch.nn as nn

#matplotlib.rcParams['text.usetex'] = True
#pretty_pyplot_layout()

np.random.seed(0)
net_dir = "/mnt/data0/emastr/article_training_nodecay/"
MESH_PATH = "/home/emastr/deep-micro-slip-model/data/mesh/"
figures_dir = "/home/emastr/deep-micro-slip-model/data/figures/"
simulation_dir = "/home/emastr/deep-micro-slip-model/data/stokes_fenics/"

# %% [markdown]
# ## Multiscale Problem
#
# We define a multiscale problem as follows. The PDE is a non-slip zero forcing Stokes flow Problem
#
# \begin{equation}
# \Delta u  - \nabla p = 0, \qquad \qquad \nabla \cdot u = 0   \qquad \text{inside}\quad \Omega
# \end{equation}
#
# with the boundary conditions
#
# \begin{equation}
# u = g,\qquad \text{on}\quad\partial\Omega
# \end{equation}
#
# the boundary is a two-dimensional pipe with corners at (0,-1) and (1,1), and a micro scale boundary:

# %% [markdown]
# ## Coupling to Micro Domain
#
# To couple the macro domain to the microscopic domain, we make use of the HMM framework.
# We construct a set of evenly spaced micro problems based on the Stokes data. The macro problem is constructed with a pre-specified resolution in the x- and y-directions.

# %%
from dataclasses import dataclass
from multiprocessing import Pool

@dataclass
class HyperParams:
    nMic: int
    n_refine: int
    xDim: int
    yDim: int
    width: float
    height: float
    tol: float
    max_iter: int
        
    
    
class Setup():
    def __init__(self, data: StokesData, param: HyperParams, net: nn.Module, net_settings: dict):
        """Create a new HMM setup with the given parameters."""
        self.params = param
        self.data = data
        
        # Macro problem
        macro = StokesMacProb(data, lambda x,a: fft_interp(x, a, dom=data.dom[0]))
        macro_solver = MacroSolver(param.xDim, param.yDim, tol=param.tol)
        
        # Micro problems
        self.xPos = np.linspace(data.dom[0][0], data.dom[0][1], param.nMic+1)[1:] - param.width/2 - (data.dom[0][1]-data.dom[0][0]) / param.nMic/1
        micros = [StokesMicProb(data, x, param.width, param.height, 0.0, 8, 5, 5, n_refine=param.n_refine) for x in self.xPos]
        micro_solvers = [MicroSolver(m, tol=param.tol) for m in micros]
        deep_micro_solvers = [DeepMicroSolver(m, net, net_settings, tol=param.tol) for m in micros]
        
        # Convergence checker
        conv_checker = ConvergenceChecker(macro, micros, tol=param.tol)
        
        # HMM problem
        self.hmm_problem = StokesHMMProblem(macro, micros, data, convergence_checker=conv_checker)
        self.hmm_solver = IterativeHMMSolver(macro_solver, micro_solvers)
        self.hmm_deep_solver = IterativeHMMSolver(macro_solver, deep_micro_solvers)
        
        
    def solve(self, **kwargs):
        macro_guess = self.hmm_solver.macro_solver.solve(self.hmm_problem.macro)
        (macro_sol, micro_sols) = self.hmm_solver.solve(self.hmm_problem, macro_guess=macro_guess, verbose=True, maxiter=self.params.max_iter, tol=self.params.tol)
        (deep_macro_sol, deep_micro_sols) = self.hmm_deep_solver.solve(self.hmm_problem, macro_guess=macro_guess, verbose=True, maxiter=self.params.max_iter, tol=self.params.tol)
        return micro_sols, macro_sol, deep_micro_sols, deep_macro_sol, macro_guess
    
    
    def save_sol(self, macro_sol, deep_macro_sol, filename):
        data = self.params.__dict__
        data['sol_u'] = macro_sol.u.eval_grid()
        data['sol_v'] = macro_sol.v.eval_grid()
        data['deep_sol_u'] = deep_macro_sol.u.eval_grid()
        data['deep_sol_v'] = deep_macro_sol.v.eval_grid()
        print(np.linalg.norm(data['sol_u'] - data['deep_sol_u'])/np.linalg.norm(data['sol_u']))
        np.save(filename, data)
        
        
    def load_sol(filename):
        data = np.load(filename, allow_pickle=True).flatten()[0]
        u = data.pop('sol_u')
        v = data.pop('sol_v')
        u_deep = data.pop('deep_sol_u')
        v_deep = data.pop('deep_sol_v')
        par = HyperParams(**data)
        return par, u, v, u_deep, v_deep

# %% [markdown]
# ## Solving using HMM iterations
#
# To solve the problem, we make use of a sequence of micro solvers, as well as a micro solver.

# %%
# range of data to use : 25 - 59
    
w_list = [1, 2, 3, 4, 5, 6, 7, 8]
n_list = [3, 5, 7, 9, 11, 13, 15, 17]
i_list = list(range(50, 60, 1))

args = [(i, n, w) for i, n, w in product(i_list, n_list, w_list)]

device = "cpu" # "cuda:0"
net, net_settings = get_net(f"/home/emastr/phd/data/runs/fnoskip_big_data_48_{40000}.Torch", 256, "cpu", "float")        

def solve_save(i, n, w):
    data, info = StokesData.load_from_matlab(f"/home/emastr/phd/data/reference_2/run_{i}.mat")
    data_big_domain = data
    dom = data.dom
    eps = info["eps"]
    print(f"i={i}, (n={n}, w={w}")
    params = HyperParams(nMic=n, n_refine=0, xDim=21, yDim=21, width=w*eps, height=w*eps*0.8, tol=1e-8, max_iter=30)
    setup = Setup(data, params, net, net_settings)
    _, macro_sol, _, deep_macro_sol, _ = setup.solve()
    setup.save_sol(macro_sol, deep_macro_sol, f"/home/emastr/phd/data/hmm_sols/sol_{i}_{n}_{w}.npy")

# %%
Pool(8).starmap(solve_save, args)
# Out:
# i=50, (n=3, w=1
# i=50, (n=13, w=1i=51, (n=7, w=1
# i=50, (n=17, w=5i=51, (n=11, w=5
#
# i=50, (n=7, w=5
#
# i=51, (n=17, w=1
# i=52, (n=5, w=5
# Convergence (not necessarily to solution) at step 10/30tep 3/30Step 11/30Step 4/30Step 12/30Step 8/30Step 0/30Step 5/30
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0004740721580776805
# i=52, (n=5, w=6
# Convergence (not necessarily to solution) at step 11/30/30Step 20/30
# 0.0006063574799917575
# Convergence (not necessarily to solution) at step 9/30
# i=50, (n=7, w=6
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 9/30
# 0.00832146379174411
# i=50, (n=3, w=2
# Convergence (not necessarily to solution) at step 9/30
# 0.0007130243723062457
# i=51, (n=11, w=6
# Convergence (not necessarily to solution) at step 10/30
# 0.002319224016826713
# i=52, (n=5, w=7
# Convergence (not necessarily to solution) at step 20/30Step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 10/30
# 0.0006096509154192527
# Convergence (not necessarily to solution) at step 9/30
# 0.0016506984618603721
# i=50, (n=17, w=6
# Step 16/30Step 22/30i=50, (n=7, w=7
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 19/30
# 0.0009356733427122164
# i=50, (n=3, w=3
# Convergence (not necessarily to solution) at step 8/30
# 0.0038517448194381465
# i=52, (n=5, w=8
# Convergence (not necessarily to solution) at step 29/30
# 0.010226239957325673
# i=51, (n=7, w=2
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 8/30
# 0.0012638316669443576Step 5/30
# i=51, (n=11, w=7
# Convergence (not necessarily to solution) at step 7/30
# 0.0056772046564734875
# Step 6/300i=52, (n=7, w=1
# Step 9/30Step 4/30Convergence (not necessarily to solution) at step 12/30
# 0.001302844157637654
# i=50, (n=3, w=4
# Convergence (not necessarily to solution) at step 8/30
# 0.003476580632913043
# i=50, (n=7, w=8
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 23/30
# 0.0070270681439377975
# Convergence (not necessarily to solution) at step 18/30
# i=50, (n=13, w=2
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 11/30
# 0.001356178855526502
# i=50, (n=3, w=5
# Convergence (not necessarily to solution) at step 7/30
# 0.005759667585150028
# Convergence (not necessarily to solution) at step 10/30
# i=50, (n=9, w=1
# Convergence (not necessarily to solution) at step 7/30
# 0.0031396179049045067
# Step 12/30i=51, (n=11, w=8
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 11/30
# 0.00044583560537741774
# i=50, (n=3, w=6
# Convergence (not necessarily to solution) at step 19/30
# 0.0010617992923173825
# i=51, (n=7, w=3
# Convergence (not necessarily to solution) at step 9/30
# 0.001598414613797816
# i=50, (n=17, w=7
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0013516912374731038
# i=50, (n=3, w=7
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 28/30
# 0.01012756014756598
# i=51, (n=17, w=2
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 6/30
# 0.005121413678255028
# i=51, (n=13, w=1
# Convergence (not necessarily to solution) at step 8/30
# 0.003568199245825051
# i=50, (n=3, w=8
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 29/30
# 0.010231665877764288
# i=52, (n=7, w=2
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 13/30
# 0.0010491318931319486
# i=51, (n=7, w=4
# Convergence (not necessarily to solution) at step 8/30
# 0.004893530389046299
# i=50, (n=5, w=1
# Convergence (not necessarily to solution) at step 16/30
# 0.0006744142407613653
# Step 9/30Step 8/30i=50, (n=13, w=3
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 8/30
# 0.003496486254428789
# i=50, (n=17, w=8
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0019530924218701298
# i=51, (n=7, w=5
# Convergence (not necessarily to solution) at step 29/30
# 0.008803980751790256
# i=50, (n=9, w=2
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 21/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 19/30
# 0.0010639585890375941
# i=52, (n=7, w=3
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 29/30
# 0.012920238422550483
# i=50, (n=5, w=2
# Convergence (not necessarily to solution) at step 11/30
# 0.0006104119799542805
# i=51, (n=7, w=6Step 5/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 7/30
# 0.00537599760662344
# i=51, (n=3, w=1
# Convergence (not necessarily to solution) at step 12/30
# 0.0007183484877118995
# Step 5/30i=50, (n=13, w=4
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 23/30
# 0.007013255632505005
# Convergence (not necessarily to solution) at step 13/30
# 0.0010483522372119903
# i=51, (n=13, w=2
# i=52, (n=7, w=4
# Convergence (not necessarily to solution) at step 18/30Step 19/30
# 0.001089964285191787Step 7/30
# i=51, (n=17, w=3
# Step 12/30Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 9/30
# 0.001656640671673129
# i=51, (n=7, w=7
# Convergence (not necessarily to solution) at step 19/30
# 0.001164922043370894
# i=50, (n=9, w=3
# Convergence (not necessarily to solution) at step 19/30
# 0.0014222556829626145
# i=50, (n=5, w=3
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 7/30
# 0.008329580044597532tep 1/30Step 6/30Step 3/30
# i=51, (n=3, w=2
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0019562245665506323
# i=52, (n=7, w=5
# Convergence (not necessarily to solution) at step 8/30
# 0.0034744828695745726
# i=51, (n=7, w=8
# Convergence (not necessarily to solution) at step 13/300/30Step 9/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 10/30
# 0.0021453892746441296
# Convergence (not necessarily to solution) at step 15/30
# i=50, (n=13, w=5
# Convergence (not necessarily to solution) at step 12/30
# 0.00128985889307424
# i=50, (n=5, w=4
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 18/30
# 0.0009370399387324732
# i=51, (n=3, w=3
# Convergence (not necessarily to solution) at step 7/30
# 0.0057389169150835655
# i=51, (n=9, w=1
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 13/30
# 0.0010870552063884352
# i=50, (n=9, w=4
# Convergence (not necessarily to solution) at step 11/30
# 0.0006111087630622271
# Convergence (not necessarily to solution) at step 12/30
# Step 0/30i=52, (n=7, w=6
# Step 8/300Step 11/30Step 0/30Step 7/30Convergence (not necessarily to solution) at step 11/30
# 0.003017458740981912
# Step 0/30i=50, (n=5, w=5
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 12/30
# 0.001303684479466644
# i=51, (n=3, w=4
# Convergence (not necessarily to solution) at step 16/30
# 0.0006755475333828444
# Convergence (not necessarily to solution) at step 9/30
# i=51, (n=13, w=3
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0010083977942501713
# i=51, (n=17, w=4
# Convergence (not necessarily to solution) at step 11/30
# 0.0013566125105745003
# i=51, (n=3, w=5
# Convergence (not necessarily to solution) at step 11/30
# 0.0004735317483044621
# Convergence (not necessarily to solution) at step 9/30
# 0.0006489660309698275
# i=50, (n=5, w=6
# Convergence (not necessarily to solution) at step 10/30
# 0.0016659153172885065
# i=50, (n=13, w=6
# i=52, (n=7, w=7
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 11/30
# 0.001830112594249501
# Step 6/30Step 2/30i=50, (n=9, w=5
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0004459705795060178
# i=51, (n=3, w=6
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 10/30
# 0.002327033823931497
# Step 7/30i=50, (n=5, w=7
# Convergence (not necessarily to solution) at step 8/30
# 0.003472554866196031
# i=52, (n=7, w=8
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0013520488946307991
# i=51, (n=3, w=7
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 8/30
# 0.003569230480334105
# i=51, (n=3, w=8
# Convergence (not necessarily to solution) at step 8/30
# 0.0038504180119013536Step 1/30
# i=50, (n=5, w=8
# Convergence (not necessarily to solution) at step 10/30
# 0.0006523803368848746Step 11/30
# i=50, (n=9, w=6
# Convergence (not necessarily to solution) at step 8/30
# 0.001451325510706592
# i=50, (n=13, w=7
# 0.008817159879380598
# Convergence (not necessarily to solution) at step 6/30
# i=51, (n=9, w=2
# Convergence (not necessarily to solution) at step 7/30
# 0.0057312020370494585
# i=52, (n=9, w=1
# Convergence (not necessarily to solution) at step 13/30
# Step 6/30Step 0/300.0007098486787729829
# i=51, (n=13, w=4
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 8/30
# 0.004894821052511895
# i=51, (n=5, w=1
# Convergence (not necessarily to solution) at step 10/30
# 0.002046547937278262
# i=51, (n=17, w=5
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 7/30
# 0.005669885114679795
# i=50, (n=7, w=1
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0015936061881134424
# i=50, (n=9, w=7
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 7/30
# 0.0026423956661300817
# i=50, (n=13, w=8
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 10/30
# 0.0021553851143756957
# i=51, (n=13, w=5
# Convergence (not necessarily to solution) at step 29/30
# 0.012922510044435747
# i=51, (n=5, w=2
# Convergence (not necessarily to solution) at step 8/30
# 0.004102312248410957
# Convergence (not necessarily to solution) at step 6/30
# i=50, (n=9, w=8
# Convergence (not necessarily to solution) at step 19/30
# 0.0011634498196854502
# i=51, (n=9, w=30/30Step 6/30
# Convergence (not necessarily to solution) at step 6/30
# 0.004238837039905942
# Convergence (not necessarily to solution) at step 10/30
# 0.0006031245663997472
# i=50, (n=15, w=1
# Convergence (not necessarily to solution) at step 6/30
# i=51, (n=17, w=6
# Convergence (not necessarily to solution) at step 28/30
# 0.008819864008446476
# i=52, (n=9, w=2Convergence (not necessarily to solution) at step 9/30
#
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 28/30
# 0.010157850516145523
# i=50, (n=7, w=2
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 7/30
# 0.00645948652282097
# i=50, (n=11, w=1
# Convergence (not necessarily to solution) at step 19/30
# 0.0014216508717604798
# i=51, (n=5, w=3
# Convergence (not necessarily to solution) at step 9/30
# 0.0006417189714485546
# i=51, (n=13, w=6
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 8/30
# 0.0010794669765800968Step 0/30
# i=51, (n=9, w=4
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0012802990897540865
# i=51, (n=5, w=4
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0015813398874216767
# Convergence (not necessarily to solution) at step 19/30
# 0.0010446399868859963
# i=51, (n=17, w=7
# i=50, (n=7, w=3
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 27/30
# Convergence (not necessarily to solution) at step 19/30
# 0.0011651788663688645
# i=52, (n=9, w=3
# Convergence (not necessarily to solution) at step 8/30
# 0.0014485437047950277
# i=51, (n=13, w=7
# Convergence (not necessarily to solution) at step 11/30
# 0.0018358866241109612
# i=51, (n=9, w=5
# Convergence (not necessarily to solution) at step 11/30
# 0.0030155272104745107
# i=51, (n=5, w=5
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 13/30
# 0.0010455385387595115
# i=50, (n=7, w=4
# Convergence (not necessarily to solution) at step 11/30
# 0.0004739381589652899
# i=51, (n=5, w=6
# Convergence (not necessarily to solution) at step 23/30
# 0.007727493644525422
# i=50, (n=15, w=2
# Convergence (not necessarily to solution) at step 10/30
# 0.0006493714552982627
# Convergence (not necessarily to solution) at step 9/30
# i=51, (n=9, w=6
# Convergence (not necessarily to solution) at step 7/30
# 0.0026342400592470647
# i=51, (n=13, w=8
# Convergence (not necessarily to solution) at step 13/30
# 0.001080529281269848
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 7/30
# 0.0035087136472706153
# i=52, (n=9, w=4
# i=51, (n=17, w=8
# Convergence (not necessarily to solution) at step 28/30
# 0.0076881091093532515
# Step 3/30Step 0/30i=50, (n=11, w=2
# Convergence (not necessarily to solution) at step 10/30
# 0.0023182026461900716
# i=51, (n=5, w=7
# Convergence (not necessarily to solution) at step 11/30Step 1/30
# 0.001943244788900095
# i=52, (n=11, w=1
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 8/30Step 4/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0016112590900018726
# Convergence (not necessarily to solution) at step 8/30
# 0.0038505765759986477
# i=51, (n=9, w=7
# i=51, (n=5, w=8
# Convergence (not necessarily to solution) at step 6/30
# 0.004252387055837601
# i=51, (n=15, w=1
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0018354582560092148
# i=52, (n=9, w=5
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 7/30
# 0.0056750127777425215
# Step 5/30Step 17/30i=52, (n=15, w=5
# Convergence (not necessarily to solution) at step 7/30
# 0.00547273729837569
# i=52, (n=3, w=1
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# 0.00411244644815726
# i=51, (n=9, w=8
# Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 16/30
# 0.0007952534384863977
# i=50, (n=11, w=3
# Convergence (not necessarily to solution) at step 15/30
# 0.0006818984976309328
# i=50, (n=15, w=3
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0006503032054701863
# i=52, (n=9, w=6
# 0.008332090998678715
# i=52, (n=3, w=2
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 7/30
# 0.006450644194854371
# i=51, (n=11, w=1
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 9/30Step 5/30
# 0.0004778984662437848
# i=52, (n=15, w=6
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 18/30
# 0.0009373006686405263
# i=52, (n=3, w=3
# Convergence (not necessarily to solution) at step 9/30
# 0.0016155648880188894
# i=52, (n=9, w=7
# Convergence (not necessarily to solution) at step 27/30
# 0.007704836405368838
# i=52, (n=11, w=2
# Convergence (not necessarily to solution) at step 11/30
# 0.0009687460169754663
# i=50, (n=11, w=4
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0013040839727518705
# i=52, (n=3, w=4
# Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 10/30
# Step 1/300Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0007732388846329837
# i=50, (n=15, w=4
# Convergence (not necessarily to solution) at step 23/30
# 0.007448748921274898Step 4/30
# i=51, (n=15, w=2
# Convergence (not necessarily to solution) at step 8/30
# 0.004112746318865618
# i=52, (n=9, w=8
# Convergence (not necessarily to solution) at step 8/30
# 0.0012262160953235908
# i=52, (n=15, w=7
# Convergence (not necessarily to solution) at step 11/30
# 0.0013570453166506723
# i=52, (n=3, w=5
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 10/30tep 9/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 10/30
# Step 6/30Step 12/300.0018975069335867218
# i=50, (n=11, w=5
# Convergence (not necessarily to solution) at step 11/30
# 0.0004461132229612891
# i=52, (n=3, w=6
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 7/30
# 0.0064529116718712864
# Convergence (not necessarily to solution) at step 9/30
# i=53, (n=5, w=1
# Convergence (not necessarily to solution) at step 9/30
# 0.0013524779632680334
# i=52, (n=3, w=7
# Convergence (not necessarily to solution) at step 16/30
# 0.0007989356995537772
# i=52, (n=11, w=3
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 27/30
# Step 5/300.0077049156184929085
# i=51, (n=11, w=2
# Convergence (not necessarily to solution) at step 7/30Step 5/30
# 0.002849523027783126
# Convergence (not necessarily to solution) at step 8/30
# 0.003570366254511184
# i=52, (n=15, w=8
# i=52, (n=3, w=8
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# 0.002072841003316472
# 0.0007085961964703563
# i=50, (n=15, w=5
# i=50, (n=11, w=6
# Convergence (not necessarily to solution) at step 8/30
# 0.004896378868690793
# Step 9/30i=52, (n=5, w=1
# Step 0/300Step 13/30Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 15/30
# 0.0006676981789263888
# 0.012930129123052431
# i=51, (n=15, w=3
# i=53, (n=5, w=2
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0009635053610882723
# i=52, (n=11, w=4
# Convergence (not necessarily to solution) at step 6/30
# 0.004791753199135246
# i=52, (n=17, w=1
# Convergence (not necessarily to solution) at step 8/30
# 0.001261154955628749
# i=50, (n=11, w=7
# Step 5/300Step 15/30Step 14/30Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0004663006287989756
# i=50, (n=15, w=6
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 16/30
# 0.0007970260923685375
# i=51, (n=11, w=3
# Convergence (not necessarily to solution) at step 6/30
# 0.012926861328426695
# i=52, (n=5, w=2
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 19/30
# 0.001422744423542101
# i=53, (n=5, w=3
# Convergence (not necessarily to solution) at step 7/30
# 0.0031239268513473693
# i=50, (n=11, w=8
# Convergence (not necessarily to solution) at step 10/30
# 0.0018831917324126828
# i=52, (n=11, w=5
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 19/30Step 14/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0007581967319787379
# i=51, (n=15, w=4
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 12/30
# 0.001281384667106045
# i=53, (n=5, w=4
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 18/30
# 0.0014223918777802418
# i=52, (n=5, w=3
# Convergence (not necessarily to solution) at step 8/30
# 0.0012371659316983076
# i=50, (n=15, w=7
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 6/30
# 0.005092159058354059
# i=53, (n=9, w=5
# Convergence (not necessarily to solution) at step 11/30
# 0.000962068978352705
# i=51, (n=11, w=4
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0007144276702963043
# i=52, (n=11, w=6
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 11/30
# 0.003017271403713743
# i=53, (n=5, w=5
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Step 7/300Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 6/30
# 0.0012810884721653948
# i=52, (n=5, w=4
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0006505904251788788
# Convergence (not necessarily to solution) at step 10/30
# i=53, (n=9, w=6Step 4/30
# Convergence (not necessarily to solution) at step 11/30
# 0.00047419243930377073
# i=53, (n=5, w=6
# Convergence (not necessarily to solution) at step 10/30Step 0/30
# 0.0020237925370765217
# i=51, (n=15, w=5
# Convergence (not necessarily to solution) at step 10/30
# 0.0018749294121388933
# i=53, (n=15, w=1
# Convergence (not necessarily to solution) at step 7/30
# 0.002844802061966996
# i=50, (n=15, w=8
# Convergence (not necessarily to solution) at step 8/30
# 0.0012636239826408322
# i=52, (n=11, w=7
# Convergence (not necessarily to solution) at step 11/30
# 0.003016505152095393
# i=54, (n=3, w=5
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30
# 0.0023198511434389738
# i=53, (n=5, w=7
# Convergence (not necessarily to solution) at step 11/30
# Step 5/300.0004463183303735032
# i=54, (n=3, w=6
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 6/30Step 27/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0016160890359634902
# i=53, (n=9, w=7
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 28/30
# 0.010134814137175242
# i=52, (n=17, w=2
# Convergence (not necessarily to solution) at step 9/30
# 0.0013530947250037276
# i=54, (n=3, w=7
# Convergence (not necessarily to solution) at step 7/30
# 0.0031409500188197357
# i=52, (n=11, w=8
# Convergence (not necessarily to solution) at step 8/30
# 0.003852723292891065
# i=53, (n=5, w=8
# Convergence (not necessarily to solution) at step 6/30
# 0.004713531792079789
# i=50, (n=17, w=1
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 8/30
# 0.003572006799032567
# i=54, (n=3, w=8
# Convergence (not necessarily to solution) at step 9/30
# 0.0004768420538610269
# i=51, (n=15, w=6
# Convergence (not necessarily to solution) at step 7/30
# 0.005678668843972779
# Convergence (not necessarily to solution) at step 6/30
# i=53, (n=7, w=1
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 8/30
# 0.004113734890359875
# i=53, (n=9, w=8
# Convergence (not necessarily to solution) at step 8/30
# 0.004898629754784018
# i=54, (n=5, w=1
# Convergence (not necessarily to solution) at step 6/30
# 0.005099701437350623
# i=52, (n=13, w=1
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 7/30
# Step 4/300Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 7/30
# 0.006454647080705097
# i=53, (n=11, w=1
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 8/30
# 0.0012257083055632692
# i=51, (n=15, w=7
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 24/30
# 0.007453542350116169
# i=53, (n=15, w=2
# 0.012932761992758645
# i=54, (n=5, w=2
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 28/30
# 0.010235650213314698
# i=53, (n=7, w=2
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 17/30
# 0.0010904281913003315
# i=52, (n=17, w=3
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 7/30
# 0.0028480084632516805
# Step 0/30Step 16/30i=51, (n=15, w=8
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 18/30
# 0.0014230448252822582
# i=54, (n=5, w=3
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 24/30
# 0.0070519781916277904
# i=52, (n=13, w=2
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 19/30
# 0.0010641067606749239
# i=53, (n=7, w=3
# Convergence (not necessarily to solution) at step 27/30
# 0.010218040985502316
# i=50, (n=17, w=2
# Convergence (not necessarily to solution) at step 12/30
# 0.0012816481495899915
# i=54, (n=5, w=4
# Convergence (not necessarily to solution) at step 27/30
# 0.0077073435300270415
# i=53, (n=11, w=2
# Convergence (not necessarily to solution) at step 6/30
# 0.0047920518896010615
# i=54, (n=9, w=1
# Convergence (not necessarily to solution) at step 14/30
# 0.0006686057890055407
# i=53, (n=15, w=3
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 11/30
# 0.00301788982698805
# i=54, (n=5, w=5
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0010102569072121808
# i=52, (n=17, w=4
# Convergence (not necessarily to solution) at step 13/30
# 0.0010485747900782075
# i=53, (n=7, w=4
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0004742896094657396
# i=54, (n=5, w=6
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 17/30
# 0.0006759880551254421
# i=52, (n=13, w=3
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 11/30
# 0.001956866748509739
# i=53, (n=7, w=5
# Convergence (not necessarily to solution) at step 10/30
# 0.002320328378856958
# i=54, (n=5, w=7
# Convergence (not necessarily to solution) at step 16/30
# 0.0007996552800337142
# i=53, (n=11, w=3
# Convergence (not necessarily to solution) at step 11/30
# 0.0007567086040345975
# i=53, (n=15, w=4
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 10/30
# Step 2/300Step 6/30Convergence (not necessarily to solution) at step 8/30
# 0.003853513382095497
# i=54, (n=5, w=8
# Convergence (not necessarily to solution) at step 29/30
# 0.00882392171425281
# i=54, (n=9, w=2
# Convergence (not necessarily to solution) at step 10/30
# 0.0020475450463900233
# i=52, (n=17, w=5
# Convergence (not necessarily to solution) at step 12/30
# Step 3/300Step 2/30Step 10/30Convergence (not necessarily to solution) at step 11/30
# 0.000611257371402434
# i=53, (n=7, w=6
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 18/30
# 0.0011156560413025701
# i=50, (n=17, w=3
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 7/30
# 0.005679834963764948
# i=54, (n=7, w=1
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0009642032694040099
# i=53, (n=11, w=4
# Convergence (not necessarily to solution) at step 12/30
# 0.000715848597545304
# i=52, (n=13, w=4
# Convergence (not necessarily to solution) at step 9/30
# 0.0016667184406861828
# i=53, (n=7, w=7
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# 0.0020211536553929135
# i=53, (n=15, w=5
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# 0.0034734023754727484
# i=53, (n=7, w=8
# Convergence (not necessarily to solution) at step 10/30
# 0.0006024458509292907
# i=52, (n=17, w=6
# Convergence (not necessarily to solution) at step 19/30
# 0.0011658333843020349
# i=54, (n=9, w=3
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 10/30
# 0.0018842216220328483
# i=53, (n=11, w=5
# Convergence (not necessarily to solution) at step 10/30
# 0.002164358712285277
# i=52, (n=13, w=5
# Convergence (not necessarily to solution) at step 7/30
# 0.00573297717474202
# Convergence (not necessarily to solution) at step 11/30
# 0.0010233339800660363
# i=53, (n=9, w=1
# Step 2/30i=50, (n=17, w=4
# Convergence (not necessarily to solution) at step 28/30
# 0.010237755936034206
# i=54, (n=7, w=2
# Convergence (not necessarily to solution) at step 12/30Step 0/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# 0.00047869598669708424
# i=53, (n=15, w=6
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30Step 14/30
# Convergence (not necessarily to solution) at step 13/30
# 0.0010811377175919405
# i=54, (n=9, w=4
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 9/30
# Step 3/300.0007150344295891855
# i=53, (n=11, w=6
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0015823757856849802
# i=52, (n=17, w=7
# Convergence (not necessarily to solution) at step 9/30
# 0.0006430457007054759
# i=52, (n=13, w=6
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 19/30
# 0.001064284667952634
# i=54, (n=7, w=3
# Convergence (not necessarily to solution) at step 8/30
# 0.0012267932672256738
# Step 5/30i=53, (n=15, w=7
# Convergence (not necessarily to solution) at step 11/30
# 0.0018363679990691837
# Convergence (not necessarily to solution) at step 10/30
# i=54, (n=9, w=5
# 0.0020868853903875015
# i=54, (n=13, w=5
# Convergence (not necessarily to solution) at step 8/30
# 0.0012650412833511023
# i=53, (n=11, w=7
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 29/30
# 0.008822112614355972
# i=53, (n=9, w=2
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# 0.0014546666484880082
# i=52, (n=13, w=7
# Convergence (not necessarily to solution) at step 13/30
# 0.0010487884953861175
# i=54, (n=7, w=4
# Convergence (not necessarily to solution) at step 7/30
# 0.0035090080224610977
# i=52, (n=17, w=8
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 7/30
# 0.003141829333595489
# i=53, (n=11, w=8
# Convergence (not necessarily to solution) at step 11/30
# 0.0006506977137757555
# Convergence (not necessarily to solution) at step 7/30
# 0.0028498274856425254
# i=54, (n=9, w=6
# i=53, (n=15, w=8
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0006440949495891737
# i=54, (n=13, w=6
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 6/30
# Step 5/300Convergence (not necessarily to solution) at step 8/30
# Step 0/30Convergence (not necessarily to solution) at step 11/30
# 0.001957272564855586
# i=54, (n=7, w=5
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 7/30
# 0.0026325644322260917
# i=52, (n=13, w=8
# Convergence (not necessarily to solution) at step 6/30
# 0.005098938423811393
# i=53, (n=13, w=1
# Convergence (not necessarily to solution) at step 9/30
# 0.0016164128140247762
# Convergence (not necessarily to solution) at step 7/30
# i=54, (n=9, w=7
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 7/30
# 0.005475285594506193
# i=53, (n=3, w=1
# Convergence (not necessarily to solution) at step 19/30
# 0.0011656034875842112
# Convergence (not necessarily to solution) at step 6/30
# 0.004790796961774795
# i=53, (n=9, w=3
# i=53, (n=17, w=1
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0006113837778371533
# i=54, (n=7, w=6
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 8/30
# 0.0014540651858917946
# i=54, (n=13, w=7
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 6/30
# 0.004232815956389852
# i=52, (n=15, w=1
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# 0.004114574673695108
# i=54, (n=9, w=8
# Convergence (not necessarily to solution) at step 29/30
# 0.008334206617784643
# Step 6/30Step 1/30i=53, (n=3, w=2
# Convergence (not necessarily to solution) at step 21/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0016670440268261066
# i=54, (n=7, w=7
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 13/30
# 0.0010809004547326687
# i=53, (n=9, w=4
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 7/30
# Step 8/30Step 9/30Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 7/30
# 0.006455982410109521
# 0.0026340978930474825
# i=54, (n=11, w=1
# i=54, (n=13, w=8
# Convergence (not necessarily to solution) at step 18/30
# 0.000937538607136554
# i=53, (n=3, w=3
# Step 16/30Step 0/30Step 21/30Step 14/30Step 8/30Convergence (not necessarily to solution) at step 8/30
# 0.0034741424152028937
# i=54, (n=7, w=8
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 6/30
# Step 11/30tep 0/30Step 1/30Step 10/30Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0013044157108519172
# i=53, (n=3, w=4
# Convergence (not necessarily to solution) at step 11/30
# 0.001835995201569845
# Convergence (not necessarily to solution) at step 23/30
# 0.007028682171027585
# i=55, (n=3, w=1
# i=53, (n=13, w=2
# Step 16/30Step 1/30Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 7/30
# 0.005734232174227524
# i=55, (n=7, w=5
# Convergence (not necessarily to solution) at step 6/30
# 0.004242133305216626
# i=54, (n=15, w=1
# Convergence (not necessarily to solution) at step 11/30Step 9/30
# 0.0013573910726937695
# i=53, (n=3, w=5
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 11/30
# 0.00044622684905845704
# Step 15/30i=53, (n=3, w=6
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0006114873111909156
# i=55, (n=7, w=6
# Convergence (not necessarily to solution) at step 29/30
# 0.008337320858270991
# i=55, (n=3, w=2
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0013528175070661968
# Step 4/300i=53, (n=3, w=7
# Convergence (not necessarily to solution) at step 24/30
# 0.00745207588874481
# Convergence (not necessarily to solution) at step 7/30
# i=52, (n=15, w=2
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 9/30
# Step 2/300Step 5/30Convergence (not necessarily to solution) at step 8/30
# 0.003571274908290386
# i=53, (n=3, w=8
# Convergence (not necessarily to solution) at step 28/30
# 0.010134542187686878
# i=53, (n=17, w=2
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 18/30
# 0.0009378897946351289
# i=55, (n=3, w=3
# Convergence (not necessarily to solution) at step 9/30
# 0.001667322717185008
# i=55, (n=7, w=7
# Convergence (not necessarily to solution) at step 8/30
# 0.004897625644045397
# i=55, (n=13, w=1
# Convergence (not necessarily to solution) at step 27/30
# 0.007708912984599357
# i=54, (n=11, w=2
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 16/30
# 0.0006745547808070133
# i=53, (n=13, w=3
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0013049047019758854
# i=55, (n=3, w=4
# Convergence (not necessarily to solution) at step 8/30
# 0.0034747322547027284
# i=55, (n=7, w=8
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0013578995648940368
# i=55, (n=3, w=5
# Convergence (not necessarily to solution) at step 6/30
# Step 10/30Step 18/30Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 7/30
# 0.005735199290721272
# i=55, (n=9, w=1
# Convergence (not necessarily to solution) at step 11/30Convergence (not necessarily to solution) at step 20/30
#
# 0.00044639391342982647
# Convergence (not necessarily to solution) at step 17/30
# i=55, (n=3, w=6
# Convergence (not necessarily to solution) at step 24/30
# 0.00745494580376994
# i=54, (n=15, w=2
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 14/30
# 0.0006683308060683648
# i=52, (n=15, w=3
# Convergence (not necessarily to solution) at step 9/30Step 0/30
# 0.0013533237769438515
# i=55, (n=3, w=7
# Step 2/300Step 2/30Convergence (not necessarily to solution) at step 16/30
# 0.0007998620643101996
# i=54, (n=11, w=3
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 13/30
# 0.0007139090731035154
# i=53, (n=13, w=430Step 1/30
# Convergence (not necessarily to solution) at step 8/30
# 0.0035726115155844595
# i=55, (n=3, w=8
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 8/30
# 0.0048994593810017095
# i=55, (n=5, w=1
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 23/30
# 0.007031320247148042
# i=55, (n=13, w=2
# Convergence (not necessarily to solution) at step 18/30
# 0.0010907317403672004
# i=53, (n=17, w=3
# Convergence (not necessarily to solution) at step 9/30
# Step 1/300Step 16/30Step 6/30Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0009644984363679178
# Convergence (not necessarily to solution) at step 11/30
# 0.0007569685077572538
# Step 8/300i=54, (n=11, w=4
# i=52, (n=15, w=4
# Convergence (not necessarily to solution) at step 10/30
# 0.002160667304302096
# i=53, (n=13, w=5
# Convergence (not necessarily to solution) at step 29/30
# 0.008825413239459358
# i=55, (n=9, w=2
# Convergence (not necessarily to solution) at step 14/30
# 0.0006688459596220265
# i=54, (n=15, w=3
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 11/30
# 0.012934936647835314
# i=55, (n=5, w=2
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 10/30
# 0.0018846020283212169
# i=54, (n=11, w=5
# Convergence (not necessarily to solution) at step 9/30
# 0.0006439984850394824
# Convergence (not necessarily to solution) at step 11/30
# i=53, (n=13, w=6
# Convergence (not necessarily to solution) at step 16/30
# 0.0006748786060127028
# i=55, (n=13, w=3
# Convergence (not necessarily to solution) at step 11/30
# 0.001009680033437804
# i=53, (n=17, w=4
# Convergence (not necessarily to solution) at step 10/30
# 0.0020191025522730234
# i=55, (n=17, w=5
# Convergence (not necessarily to solution) at step 18/30
# 0.0014232846658459562Step 7/30
# i=55, (n=5, w=3
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 19/30
# 0.0011660292574561446
# i=55, (n=9, w=3
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0007570296618162691
# i=54, (n=15, w=4
# Convergence (not necessarily to solution) at step 9/30
# 0.0007151756999581755
# i=54, (n=11, w=6
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0012818651646566335
# i=55, (n=5, w=4
# Convergence (not necessarily to solution) at step 8/30
# 0.0014546311342903534
# i=53, (n=13, w=7
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0007145116409022688
# i=55, (n=13, w=4
# Convergence (not necessarily to solution) at step 11/30
# 0.0030184007524574107
# i=55, (n=5, w=5
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 13/30
# 0.0010813231643565801
# i=55, (n=9, w=4
# Convergence (not necessarily to solution) at step 8/30
# 0.0012654876524400397
# i=54, (n=11, w=7
# Convergence (not necessarily to solution) at step 10/30
# 0.0006024604649180542
# Convergence (not necessarily to solution) at step 11/30
# 0.0020469014292887407
# i=55, (n=17, w=6
# i=53, (n=17, w=5
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 7/30
# 0.0026336560646769733
# i=53, (n=13, w=8
# Convergence (not necessarily to solution) at step 10/30
# 0.0020208284193793764
# Step 5/30i=54, (n=15, w=5
# ...
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 7/30
# 0.002851509456754825
# i=56, (n=15, w=8
# Convergence (not necessarily to solution) at step 10/30
# 0.003653296520660203
# i=58, (n=11, w=5
# Convergence (not necessarily to solution) at step 9/30
# 0.0009765508854800015
# i=58, (n=7, w=6
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 14/30
# 0.002093320306013307
# i=59, (n=5, w=4
# Convergence (not necessarily to solution) at step 9/30
# 0.0020519103465908737
# i=57, (n=13, w=7
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 6/30
# 0.006422427587627818
# i=58, (n=3, w=1
# Convergence (not necessarily to solution) at step 8/30
# 0.002370702547624857
# i=58, (n=7, w=7
# Convergence (not necessarily to solution) at step 11/30
# 0.003370531779412919
# i=59, (n=5, w=5
# Convergence (not necessarily to solution) at step 6/30
# 0.004795269474638773
# i=59, (n=13, w=5
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 10/30
# 0.00010404269434113102
# i=58, (n=11, w=6
# Convergence (not necessarily to solution) at step 7/30Step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0011854360795633724
# Convergence (not necessarily to solution) at step 7/30
# 0.004510841316853181
# i=58, (n=15, w=4
# i=58, (n=7, w=8
# Convergence (not necessarily to solution) at step 10/30
# 0.0007000440006360531
# i=59, (n=5, w=6
# Convergence (not necessarily to solution) at step 8/30
# 0.004951734321680411
# i=57, (n=13, w=8
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0177702332903064
# i=58, (n=3, w=2
# 0.014962079116530481
# i=59, (n=9, w=2
# Convergence (not necessarily to solution) at step 7/30
# 0.008106904952979967
# i=58, (n=9, w=1
# Convergence (not necessarily to solution) at step 9/30
# 0.002888554708404454
# Convergence (not necessarily to solution) at step 7/30
# i=59, (n=5, w=7
# 0.004909667052629154
# Convergence (not necessarily to solution) at step 6/30
# i=58, (n=11, w=7
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0011306003239495979
# i=59, (n=13, w=6
# Convergence (not necessarily to solution) at step 7/30
# Step 9/300.008170844615748468
# i=57, (n=15, w=1
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 8/30
# 0.005364868978461462
# Convergence (not necessarily to solution) at step 19/30
# 0.0011588679098805405
# i=59, (n=5, w=8
# i=58, (n=3, w=3
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 5/30
# 0.012153986987911456
# i=58, (n=11, w=8
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 10/30
# 0.0029960473239827833
# i=58, (n=15, w=5
# Convergence (not necessarily to solution) at step 7/30
# 0.010198443095753344
# i=59, (n=7, w=1
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0022137551014018804
# i=58, (n=3, w=4
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0032633442999000714
# i=58, (n=3, w=5
# Convergence (not necessarily to solution) at step 18/30
# 0.0017814505725947624
# Convergence (not necessarily to solution) at step 5/30
# 0.019046272715635526
# i=59, (n=9, w=3
# i=58, (n=13, w=1
# Convergence (not necessarily to solution) at step 9/30
# 0.0020423634955852384
# i=59, (n=13, w=7Step 15/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0006964409137199464
# Convergence (not necessarily to solution) at step 21/30
# i=58, (n=3, w=6
# Convergence (not necessarily to solution) at step 28/30
# 0.015076967995860687
# i=58, (n=9, w=2
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0017980267787464034
# i=58, (n=3, w=7
# Convergence (not necessarily to solution) at step 9/30
# 0.0010536031854257218
# i=58, (n=15, w=6
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30Step 8/30
# 0.005020899642278584
# Convergence (not necessarily to solution) at step 12/30
# 0.0016322344084636357
# i=59, (n=13, w=8
# i=59, (n=9, w=4
# Convergence (not necessarily to solution) at step 8/30
# 0.004802671458336846
# i=58, (n=3, w=8
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 23/30
# 0.011803291163783454
# i=59, (n=7, w=2
# Convergence (not necessarily to solution) at step 7/30
# 0.007928658095526927
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 24/30
# 0.011167577678828132
# i=57, (n=15, w=230
# Convergence (not necessarily to solution) at step 10/30
# 0.0034794443017634965
# i=59, (n=9, w=5
# Convergence (not necessarily to solution) at step 7/30
# 0.008140061500390195
# i=59, (n=15, w=1
# Convergence (not necessarily to solution) at step 8/30
# 0.001449285128592248
# i=58, (n=15, w=7
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 21/30
# 0.001807159986224813
# i=58, (n=9, w=3
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 12/30
# 0.015017453734594736
# Convergence (not necessarily to solution) at step 14/30
# i=58, (n=13, w=2
# Convergence (not necessarily to solution) at step 10/30
# 0.0012735545738978224
# i=59, (n=9, w=6
# Convergence (not necessarily to solution) at step 22/30
# 0.0013360073098106526
# i=59, (n=7, w=3
# Convergence (not necessarily to solution) at step 7/30
# 0.004053198935623256
# i=58, (n=15, w=8
# Convergence (not necessarily to solution) at step 12/30
# 0.0016339113646509627
# i=58, (n=9, w=4
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 21/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0019854087482147004
# i=59, (n=9, w=7
# Convergence (not necessarily to solution) at step 15/30
# 0.0011007503772661853
# i=57, (n=15, w=3
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 14/30
# 0.0014716237196323514
# i=59, (n=7, w=4
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 10/30
# 0.0035247877737883317
# Convergence (not necessarily to solution) at step 6/30
# 0.007019997927140457
# i=58, (n=17, w=1
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 8/30
# 0.005055388404645864
# i=59, (n=9, w=8
# Convergence (not necessarily to solution) at step 10/30
# 0.003094001542793263
# Convergence (not necessarily to solution) at step 11/30
# i=59, (n=7, w=5
# Step 6/300Step 5/30Convergence (not necessarily to solution) at step 24/30
# 0.011313600944825851
# i=59, (n=15, w=2
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 18/30
# 0.0015781734063708087
# i=58, (n=13, w=3
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 7/30
# 0.008174726482306825
# i=59, (n=11, w=1
# Convergence (not necessarily to solution) at step 9/30
# 0.0009782668005276216
# i=59, (n=7, w=6
# Convergence (not necessarily to solution) at step 12/30
# 0.0011569769117762828
# i=57, (n=15, w=4
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 8/30
# 0.0023238696407207014
# i=59, (n=7, w=7
# Convergence (not necessarily to solution) at step 21/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0015017488116536371
# i=58, (n=13, w=4
# Convergence (not necessarily to solution) at step 7/30
# 0.004493609214244439
# i=59, (n=7, w=8
# Convergence (not necessarily to solution) at step 15/30
# 0.0011395076498939409
# i=59, (n=15, w=3
# Convergence (not necessarily to solution) at step 10/30
# 0.0029989434287340205
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 22/30
# 0.017810028458352917
# i=59, (n=11, w=2
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 7/30
# 0.008156925326275523
# Convergence (not necessarily to solution) at step 23/30
# 0.011201187331756726
# i=58, (n=17, w=2
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 11/30
# 0.003312835398943808
# i=58, (n=13, w=5
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0012045914064470525
# i=59, (n=15, w=4
# Convergence (not necessarily to solution) at step 13/30
# 0.0023146999723775855
# i=59, (n=11, w=3
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 11/30
# 0.001117081451798717
# Convergence (not necessarily to solution) at step 9/30
# i=58, (n=13, w=6
# Convergence (not necessarily to solution) at step 14/30
# 0.001128231292359375
# i=58, (n=17, w=3
# Convergence (not necessarily to solution) at step 10/30
# 0.005174151103905336
# i=59, (n=11, w=4
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# 0.003074850822528755
# i=59, (n=15, w=5
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# 0.002000988624117783
# i=58, (n=13, w=7
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# 0.0036547135726012875
# i=59, (n=11, w=5
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0010440671747281272
# i=59, (n=15, w=6
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# 0.005002058404231499
# i=58, (n=13, w=8
# Convergence (not necessarily to solution) at step 12/30
# 0.0013763352914269095
# i=58, (n=17, w=4
# Convergence (not necessarily to solution) at step 9/30
# 0.00010408097072849447
# i=59, (n=11, w=6
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 7/30
# 0.008255563753605774
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 8/30
# 0.0014758674552902144
# i=59, (n=15, w=7
# Convergence (not necessarily to solution) at step 7/30
# 0.004911625361969994
# i=59, (n=11, w=7
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 11/30
# 0.003120367174070764
# i=58, (n=17, w=5
# Convergence (not necessarily to solution) at step 5/30
# 0.0121588835960329
# i=59, (n=11, w=8
# Convergence (not necessarily to solution) at step 7/30
# 0.00406849351492637
# i=59, (n=15, w=8
# Convergence (not necessarily to solution) at step 6/30
# Step 2/30Step 5/30Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 5/30
# 0.01905404700429253
# i=59, (n=13, w=1
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 6/30
# 0.006934229604640179
# i=59, (n=17, w=1
# Convergence (not necessarily to solution) at step 9/30
# 0.001089394131486888
# i=58, (n=17, w=6
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# 0.0014798435160154866
# i=58, (n=17, w=7
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 29/30
# 0.015149965000173841
# i=59, (n=13, w=2
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 7/30
# 0.003518323098229844
# i=58, (n=17, w=8
# Convergence (not necessarily to solution) at step 24/30
# 0.011195294333468643
# i=59, (n=17, w=2
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 6/30
# 0.006420804630647747
# i=59, (n=3, w=1
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 18/30
# 0.0016122470155922053
# i=59, (n=13, w=3
# Convergence (not necessarily to solution) at step 24/30
# 0.01776786937331109
# i=59, (n=3, w=2
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 15/30
# 0.00112754336793872
# i=59, (n=17, w=3
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 19/30
# 0.0011573566273517912
# i=59, (n=3, w=3
# Convergence (not necessarily to solution) at step 12/30
# 0.0015135741751569163
# i=59, (n=13, w=4
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 12/30
# 0.0022135749754609627
# i=59, (n=3, w=4
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 11/30
# 0.0032645776960628864
# Convergence (not necessarily to solution) at step 11/30
# 0.0033749430590921626
# Convergence (not necessarily to solution) at step 12/30
# 0.0013640482782056056
# i=59, (n=17, w=4
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# 0.003120239465715781
# i=59, (n=17, w=5
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# 0.0010722553565209539
# i=59, (n=17, w=6
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# 0.0014818052567344856
# i=59, (n=17, w=7
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 7/30
# 0.003502361376221666
# i=59, (n=17, w=8
# Convergence (not necessarily to solution) at step 6/30
# Convergence (not necessarily to solution) at step 6/30
# 0.006459815969787643
