# %%
import numpy as np
import matplotlib.pyplot as plt
from util.logger import EventTracker
from util.basis_scaled import *
from util.plot_tools import *
from boundary_solvers.gauss_grid_2d import StokesDirichletProblem
from scipy.io import loadmat
import matplotlib.pyplot as plt
from util.interp import PiecewiseInterp2D
from hmm.stokes import *
from itertools import product
from hmm.stokes_deep import DeepMicroSolver, get_net
import matplotlib
import torch.nn as nn

#matplotlib.rcParams['text.usetex'] = True
#pretty_pyplot_layout()

np.random.seed(0)
net_dir = "/mnt/data0/emastr/article_training_nodecay/"
MESH_PATH = "/home/emastr/deep-micro-slip-model/data/mesh/"
figures_dir = "/home/emastr/deep-micro-slip-model/data/figures/"
simulation_dir = "/home/emastr/deep-micro-slip-model/data/stokes_fenics/"
run_dir = "/home/emastr/deep-micro-slip-model/data/reference_2/"

#save_dir = "/home/emastr/deep-micro-slip-model/data/hmm_coupling_error/"
save_dir = "/mnt/data0/emastr/hmm_coupling_paper/"

# %%
from dataclasses import dataclass
from multiprocessing import Pool

@dataclass
class HyperParams:
    nMic: int
    xDim: int
    yDim: int
    width: float
    height: float
    tol: float
    max_iter: int
    num_pts: int
    line_pos: float
    
    
class Setup():
    def __init__(self, data: StokesData, param: HyperParams):#, net: nn.Module, net_settings: dict):
        """Create a new HMM setup with the given parameters."""
        self.params = param
        self.data = data
        
        # Macro problem
        macro = StokesMacProb(data, lambda x,a: fft_interp(x, a, dom=data.dom[0]))
        macro_solver = MacroSolver(param.xDim, param.yDim, tol=param.tol)
        
        # Micro problems
        self.xPos = np.linspace(data.dom[0][0], data.dom[0][1], param.nMic+1)[1:] - param.width/2 - (data.dom[0][1]-data.dom[0][0]) / param.nMic/1
        micros = [StokesTrapezMicProb(data, x, param.width, param.height, param.line_pos, 8, param.xDim, param.yDim, num_pts=param.num_pts) for x in self.xPos]
        micro_solvers = [MicroSolver(m, tol=param.tol) for m in micros]
        #deep_micro_solvers = [DeepMicroSolver(m, net, net_settings, tol=param.tol) for m in micros]
        
        # Convergence checker
        conv_checker = ConvergenceChecker(macro, micros, tol=param.tol)
        
        # HMM problem
        self.hmm_problem = StokesHMMProblem(macro, micros, data, convergence_checker=conv_checker)
        self.hmm_solver = IterativeHMMSolver(macro_solver, micro_solvers)
        #self.hmm_deep_solver = IterativeHMMSolver(macro_solver, deep_micro_solvers)
        
        
    def solve(self, **kwargs):
        macro_guess = self.hmm_solver.macro_solver.solve(self.hmm_problem.macro)
        (macro_sol, micro_sols) = self.hmm_solver.solve(self.hmm_problem, macro_guess=macro_guess, verbose=True, maxiter=self.params.max_iter, tol=self.params.tol)
        #(deep_macro_sol, deep_micro_sols) = self.hmm_deep_solver.solve(self.hmm_problem, macro_guess=macro_guess, verbose=True, maxiter=self.params.max_iter, tol=self.params.tol)
        
        return micro_sols, macro_sol, macro_guess #deep_micro_sols, deep_macro_sol, macro_guess
    
    
    def save_sol(self, macro_sol, filename):
        data = self.params.__dict__
        data['mic_sol'] = [m.avg_vec for m in self.hmm_solver.micro_solvers]
        data['sol_u'] = macro_sol.u.eval_grid()
        data['sol_v'] = macro_sol.v.eval_grid()
        #data['deep_sol_u'] = deep_macro_sol.u.eval_grid()
        #data['deep_sol_v'] = deep_macro_sol.v.eval_grid()
        #print(np.linalg.norm(data['sol_u'] - data['deep_sol_u'])/np.linalg.norm(data['sol_u']))
        np.save(filename, data)
        
    @staticmethod
    def load_sol(filename):
        data = np.load(filename, allow_pickle=True).flatten()[0]
        u = data.pop('sol_u')
        v = data.pop('sol_v')
        m = data.pop('mic_sol')
        #u_deep = data.pop('deep_sol_u')
        #v_deep = data.pop('deep_sol_v')
        par = HyperParams(**data)
        return par, u, v, m#, u_deep, v_deep
    
    
w_list = [4.5, 5, 7, 8]#[3,5,10]#[2,5,7]
height_list = [0.8, 0.7, 1.0]#[0.8, 0.5, 1.0]
line_pos_list = [0.0, 0.01, 0.05, 0.1, 0.2]#[0.0, 0.01, 0.1]

from multiprocessing import Pool
#step = [1]#[1, 2, 3, 4, 6, 8, 11, 16, 22, 32, 46, 64]#, 128]
step = [1, 2, 3, 4, 6, 8, 11, 16, 22, 32, 46, 64]#, 128]
#M_list = [256]#[s * 20 for s in step]
M_list = [s * 20 for s in step]
#i_list = list(range(2,80,8))#:list(range(50,60,1))
i_list = [2, 42-16, 42, 42+16]#

data_product = product(M_list, w_list, height_list, line_pos_list)
data_product_list = list(data_product)

print(len(i_list)*len(data_product_list), (5952-192)/2)
# Out:
# 2880 2880.0

# %%
for i in i_list:
    
    def run(args):
        m, w, h, lp = args
        with open(f"/home/emastr/deep-micro-slip-model/data/logs/classical_log.txt", "a") as f:
            f.write(f"START --- Running sim {i} with {m} pts, {w} width, {h} height, {lp} line pos \n")
        
        data, info = StokesData.load_from_matlab(f"{run_dir}run_{i}.mat")
        data_big_domain = data
        dom = data.dom
        eps = info["eps"]
        n = 7
        
        params = HyperParams(nMic=n, xDim=21, yDim=21, width=w*eps, height=w*eps*h, tol=1e-8, max_iter=30, num_pts=m, line_pos=lp)
        setup = Setup(data, params)
        micro_sols, macro_sol, macro_guess = setup.solve()
        setup.save_sol(macro_sol, f"{save_dir}big_run_{i}_{m}_{w}_{h}_{lp}_sol.npy")
                
        with open(f"/home/emastr/deep-micro-slip-model/data/logs/classical_log.txt", "a") as f:
            f.write(f"----- END Running sim {i} with {m} pts, {w} width, {h} height, {lp} line pos \n")
    
    p = Pool(16)
    p.map(run, data_product_list)
#    for m in M_list:
#        print(f"Solving sim {i} with {m} discretisation points")
#        data, info = StokesData.load_from_matlab(f"{run_dir}run_{i}.mat")
#        data_big_domain = data
#        dom = data.dom
#        eps = info["eps"]
#        n = 7
#        w = 5#
#
#        params = HyperParams(nMic=n, xDim=21, yDim=21, width=w*eps, height=w*eps*0.8, tol=1e-8, max_iter=30, num_pts=m)
#        setup = Setup(data, params)
#        micro_sols, macro_sol, macro_guess = setup.solve()#
#
#        problem = StokesTrapezMicProb(data, 0.0, params.width, params.height, 0.0, 8, params.xDim, params.yDim, num_pts=m)
#        solver = MicroSolver(problem, tol=1e-10)
#        setup.save_sol(macro_sol, f"{save_dir}big_run_{i}_{m}_sol.npy")
# Out:
# Convergence (not necessarily to solution) at step 7/30Step 0/30Step 0/30Step 0/30Step 1/30Step 1/30Step 7/30Step 5/30Step 8/30Step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/3021/30Step 2/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Step 5/300Convergence (not necessarily to solution) at step 9/30
# Step 0/300Step 4/30Step 0/30Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 21/30
# Convergence (not necessarily to solution) at step 21/30
# Convergence (not necessarily to solution) at step 7/30
# Step 25/30Step 29/30Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30Step 3/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 8/30
# Step 10/30Step 28/30Step 9/30Step 9/30Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 27/301/30Step 10/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 17/30Step 10/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 7/30
# Step 0/300Step 21/30Step 14/30Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 27/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 27/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 21/30Step 9/30Step 4/30
# Convergence (not necessarily to solution) at step 9/300Step 11/30Step 10/30Step 4/30
# Step 6/300Step 1/30Step 8/30Convergence (not necessarily to solution) at step 8/30
# Step 2/300Step 11/30Step 8/30Convergence (not necessarily to solution) at step 8/30Step 9/30Convergence (not necessarily to solution) at step 9/30
#
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/300Step 14/30Step 18/30Step 10/30Step 11/30Step 13/30Step 17/30Step 3/30Step 8/30Step 4/30Step 19/30Step 11/30Step 1/30Step 4/30
# Step 17/30Step 18/30Step 4/30Step 0/30Step 6/30Step 11/30Step 12/30Step 2/30Step 5/30Step 5/30Step 12/30Step 1/30Step 7/30Step 14/30Step 6/30Step 16/30Step 11/30Convergence (not necessarily to solution) at step 19/30
# Step 8/300tep 13/30Step 7/30Step 15/30Convergence (not necessarily to solution) at step 16/30Step 12/30
# Step 16/30Step 1/30Step 16/30Step 3/30Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/307/30Step 25/30Step 7/30
# Step 15/30Step 4/30Step 2/30Step 3/30Step 21/30Step 16/30Step 19/30Step 12/30Step 3/30Step 9/30Step 6/30Step 19/30Step 18/30Step 24/30Step 21/30Step 5/30Step 20/30Step 4/30Step 8/30Step 7/30Step 22/30Step 5/30Step 6/30Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/3030Step 26/30
# Convergence (not necessarily to solution) at step 9/302/30Step 2/30
# Convergence (not necessarily to solution) at step 9/3030Step 4/30Step 6/30Step 16/30Step 9/30Step 27/30Step 19/30Step 28/30Step 2/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 8/30/30Step 13/30Step 7/30Step 7/30Step 14/30
# Convergence (not necessarily to solution) at step 8/30/30Step 0/30Step 4/30Step 16/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 27/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 11/30Step 19/30
# Convergence (not necessarily to solution) at step 21/30
# Convergence (not necessarily to solution) at step 27/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 27/30
# Convergence (not necessarily to solution) at step 9/30Step 4/30
# Convergence (not necessarily to solution) at step 7/30/30Step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 9/30/30Step 7/30
# Convergence (not necessarily to solution) at step 9/3011/30Step 11/30
# Convergence (not necessarily to solution) at step 9/3013/30Step 21/30
# Step 16/30Step 14/30Step 22/30Step 5/30Convergence (not necessarily to solution) at step 21/30
# Convergence (not necessarily to solution) at step 22/30
# Step 12/30Step 6/30Step 9/30Step 0/30Step 16/30Step 17/30Step 11/30Step 2/30Step 3/30Step 5/30Step 2/30Step 9/30Step 6/30Step 18/30Step 4/30Step 22/30Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 10/30/30Step 8/30Step 20/30Step 5/30Step 23/30Step 20/30Step 21/30Step 2/30Step 15/30Step 6/30Step 21/30Step 13/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 15/30/30Step 29/30Step 25/30Step 11/30Step 7/30Step 8/30Step 1/30Step 8/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 20/30
# Step 4/300Step 27/30Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 8/30Step 11/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 21/30/30Step 18/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30/30Step 29/30
# Convergence (not necessarily to solution) at step 10/3030Step 0/30Step 8/30Step 6/30Step 2/30Step 5/30Step 10/30Step 29/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 17/300Step 13/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 15/30Step 5/30Step 0/30Step 4/30Step 5/30Step 2/30Step 7/30Step 1/30Step 3/30Step 6/30
# Convergence (not necessarily to solution) at step 8/3030Step 19/30Step 18/30Step 3/30Step 5/30Step 7/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/303/30Step 7/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 7/30Step 0/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 25/30Step 6/30
# Convergence (not necessarily to solution) at step 8/30/30Step 11/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Step 3/300Step 23/30Step 3/30Step 4/30Step 20/30Step 15/30Step 2/30Step 8/30Step 0/30Step 3/30Step 2/30Step 4/30Step 9/30Step 22/30Step 29/30Step 6/30Step 1/30Step 4/30Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 17/3030Step 8/30Step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 7/30
# Step 16/30e (not necessarily to solution) at step 9/30
# Step 15/30Step 11/30Step 3/30Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 25/30
# Step 0/300Step 7/30Step 10/30Step 6/30Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 10/30Step 7/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30/30Step 11/30Step 1/30Step 15/30Step 2/30Step 8/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 26/308/30Step 15/30Step 5/30
# Convergence (not necessarily to solution) at step 8/30/30Step 6/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 17/30Step 0/30Step 22/30
# Convergence (not necessarily to solution) at step 8/30
# Step 15/30Step 11/30Step 24/30Step 28/30Step 10/30Step 13/30Step 7/30Step 2/30Step 5/30Step 24/30Step 19/30Step 3/30Step 29/30Step 3/30Step 14/30Step 4/30Step 20/30Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 14/3030Step 7/30Step 9/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 8/30Step 8/30
# Convergence (not necessarily to solution) at step 9/3030
# Convergence (not necessarily to solution) at step 8/30
# Step 15/30Step 0/30Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 19/30Step 18/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30Step 21/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 8/30 5/30Step 0/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 8/30Step 0/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/300Step 10/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/3010/30Step 29/30Step 0/30Step 11/30Step 5/30Step 12/30Step 12/30Step 6/30Step 6/30Step 28/30Step 6/30Step 13/30
# Convergence (not necessarily to solution) at step 17/3030Step 2/30Step 12/30Step 17/30Step 5/30Step 26/30Step 11/30Step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Step 8/300Step 7/30Step 15/30Step 0/30Step 5/30Step 0/30Step 19/30Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 12/3030Step 11/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 24/30/30Step 14/30Step 19/30Step 26/30Step 25/30Step 0/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30/30Step 2/30Step 7/30Step 8/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/3030Step 28/30Step 11/30Step 8/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 9/3013/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 19/3030Step 21/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 9/300Step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 14/30Step 0/30Step 2/30Step 1/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 7/30Step 16/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/3030Step 20/30Step 8/30Step 3/30Step 21/30Step 22/30Step 8/30Step 7/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/308/30Step 2/30Step 27/30Step 12/30Step 9/30Step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 9/30
# Step 6/300Step 7/30Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/3030Step 4/30Step 19/30Step 8/30
# Convergence (not necessarily to solution) at step 8/3030Step 7/30Step 22/30Step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Step 20/30e (not necessarily to solution) at step 25/30Step 18/30
# Convergence (not necessarily to solution) at step 21/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 16/3030Step 3/30Step 23/30Step 1/30Step 25/30Step 2/30Step 3/30Step 2/30
# Convergence (not necessarily to solution) at step 12/3030Step 4/30Step 4/30Step 7/30Step 25/30Step 3/30Step 27/30Step 5/30Step 9/30Step 1/30Step 6/30Step 9/30Step 26/30Step 8/30Step 6/30Step 10/30Step 10/30Step 10/30Step 10/30Step 10/30Step 28/30Step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Step 0/300Step 1/30Step 0/30Step 3/30Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 18/300Step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 9/30
# Step 1/300Step 0/30Step 8/30Step 16/30Step 20/30Step 16/30Step 29/30
# Convergence (not necessarily to solution) at step 18/30tep 12/30Step 10/30Step 16/30Step 2/30Step 17/30Step 2/30Step 3/30Step 4/30Step 19/30Step 3/30
# Convergence (not necessarily to solution) at step 9/30/30Step 21/30Step 7/30Step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 9/30
# Step 12/30Step 3/30Step 28/30Step 2/30Step 4/30Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Step 7/300Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30/30Step 22/30Step 22/30Step 18/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 11/300Step 4/30Step 7/30Step 17/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 7/30Step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 14/30/30Step 1/30Step 15/30Step 3/30
# Convergence (not necessarily to solution) at step 16/30Step 2/30
# Convergence (not necessarily to solution) at step 9/30/30Step 18/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 9/30Step 1/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30Step 6/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 9/30
# Step 0/300Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 24/30Step 1/30Step 1/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 17/30
# Step 2/300Step 2/30Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 14/3013/30Step 16/30Step 0/30Step 8/30Step 9/30
# Convergence (not necessarily to solution) at step 11/300
# Step 22/30Step 27/30Step 18/30Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30Step 9/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 8/30Step 0/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 7/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 8/300Step 1/30Step 1/30Step 1/30Step 1/30Step 2/30Step 2/30Step 2/30Step 8/30Step 7/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 12/30Step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 9/3015/30Step 13/30Step 14/30Step 14/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 9/30Step 27/30
# Step 20/30Step 18/30Convergence (not necessarily to solution) at step 8/30Step 7/30
# Convergence (not necessarily to solution) at step 10/30/30Step 26/30Step 19/30Step 8/30Step 24/30Step 1/30Step 9/30Step 5/30Step 9/30Step 19/30Step 19/30Step 25/30Step 6/30Step 28/30
# Convergence (not necessarily to solution) at step 23/30Step 3/30
# Convergence (not necessarily to solution) at step 8/30/30Step 23/30Step 1/30Step 27/30
# Convergence (not necessarily to solution) at step 24/300Step 23/30Step 5/30Step 13/30Step 2/30Step 3/30Step 24/30Step 3/30Step 7/30Step 9/30Step 4/30Step 8/30Step 3/30
# Step 26/30Step 7/30Convergence (not necessarily to solution) at step 9/30Step 3/30
# Step 5/300Step 4/30Step 27/30Step 1/30Step 16/30Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/308/30Step 27/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 23/30Step 20/30
# Convergence (not necessarily to solution) at step 14/30Step 4/30
# Step 6/300Step 1/30Step 24/30Step 1/30Step 12/30Convergence (not necessarily to solution) at step 28/30
# Convergence (not necessarily to solution) at step 26/3030Step 21/30Step 3/30Step 14/30Step 3/30Step 22/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Step 25/30Step 1/30Step 9/30Step 2/30Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 19/300Step 26/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 26/30
# Step 11/30tep 1/30Step 12/30Step 13/30Step 0/30Step 8/30Step 1/30Step 3/30Step 4/30Step 9/30Step 9/30Step 13/30Step 12/30Step 15/30Step 5/30Step 10/30Step 10/30Step 3/30Step 2/30Step 6/30Step 13/30Step 4/30Step 3/30Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 21/30/30Step 7/30Step 21/30Step 12/30
# Convergence (not necessarily to solution) at step 12/30Step 13/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 29/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 10/3030Step 9/30Step 11/30Step 23/30
# Convergence (not necessarily to solution) at step 10/30Step 22/30
# Convergence (not necessarily to solution) at step 9/3030Step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Step 11/30Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 28/30
# Convergence (not necessarily to solution) at step 10/30
# Step 3/300Step 23/30Step 26/30Step 8/30Step 2/30Step 11/30Step 7/30Step 1/30Step 27/30Step 24/30Step 11/30Step 9/30Convergence (not necessarily to solution) at step 9/30
# Step 26/30tep 5/30Step 0/30Step 28/30Step 2/30Step 9/30Step 4/30Step 4/30Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 9/30
# Step 4/300Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 10/30
# Step 6/300Step 5/30Step 1/30Step 0/30Step 15/30Step 29/30Step 1/30Step 1/30Step 23/30Step 7/30Step 2/30Step 4/30Step 6/30Step 7/30Step 29/30Step 5/30Step 2/30Step 8/30Step 9/30Step 10/30Step 2/30Step 9/30Step 26/30Step 17/30Step 13/30Step 8/30Step 11/30Step 6/30Step 3/30Step 4/30Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30Step 23/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 25/3030Step 4/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 11/30Convergence (not necessarily to solution) at step 11/30
#
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 21/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 14/30/30Step 8/30Step 14/30Step 7/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/3030Step 0/30Step 10/30Step 8/30
# Convergence (not necessarily to solution) at step 10/3030Step 21/30
# Convergence (not necessarily to solution) at step 9/309/30Step 5/30Step 6/30Step 6/30
# Convergence (not necessarily to solution) at step 15/300Step 15/30Step 14/30Step 23/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30/30Step 1/30Step 22/30Step 4/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 8/30/30Step 29/30
# Convergence (not necessarily to solution) at step 27/30Step 5/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 29/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30Step 9/30
# Convergence (not necessarily to solution) at step 9/303/30Step 1/30Step 20/30Step 16/30
# Convergence (not necessarily to solution) at step 12/30Step 18/30
# Convergence (not necessarily to solution) at step 21/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 9/30
# Step 20/30Step 0/30Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 21/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 21/30
# Convergence (not necessarily to solution) at step 28/30
# Convergence (not necessarily to solution) at step 9/30
# Step 2/300Step 0/30Convergence (not necessarily to solution) at step 21/30
# Convergence (not necessarily to solution) at step 10/30
# Step 20/30Step 9/30Step 14/30Step 24/30Step 9/30Step 2/30Step 1/30Step 25/30Step 16/30Step 1/30Step 19/30Step 10/30Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/3016/30Step 26/30
# Convergence (not necessarily to solution) at step 28/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/300Step 5/30Step 24/30Step 6/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 26/30/30Step 15/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 18/300Step 22/30Step 12/30Step 14/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 23/30
# Convergence (not necessarily to solution) at step 9/30Step 5/30Step 27/30Step 12/30Step 8/30Step 8/30
# Step 3/300Step 10/30Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 13/30
# Step 0/300Step 1/30Step 10/30Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30Step 23/30Step 7/30
# Step 12/30Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Step 0/300Convergence (not necessarily to solution) at step 10/30
# Step 2/300Step 8/30Step 3/30Step 5/30Step 9/30Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 9/30
# Step 6/300tep 11/30Step 28/30Step 16/30Step 2/30Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 28/30
# Step 13/30Step 7/30Step 17/30Step 4/30Convergence (not necessarily to solution) at step 10/30Step 18/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 10/30Step 3/30Step 9/30Step 2/30Step 5/30Step 8/30Step 4/30Step 26/30Step 5/30Step 3/30Step 23/30Step 9/30Step 8/30Step 18/30Step 27/30Step 5/30
# Convergence (not necessarily to solution) at step 9/3011/30Step 5/30Step 17/30Step 9/30Step 9/30Step 21/30Step 12/30Step 12/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/300Step 0/30
# Convergence (not necessarily to solution) at step 8/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 20/3030Step 3/30
# Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/300Step 7/30
# Convergence (not necessarily to solution) at step 8/30Step 9/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 23/30
# ...
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 9/30
# Step 4/300Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30/30Step 16/30
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 10/300Step 5/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Step 13/30Step 12/30Step 17/30Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 12/30
# Step 20/30Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 13/30Step 8/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 11/3030Step 13/30Step 26/30Step 3/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 9/30Step 9/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 29/30
# Convergence (not necessarily to solution) at step 16/30Step 13/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/300Step 25/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 27/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/3030Step 5/30
# Step 20/30Convergence (not necessarily to solution) at step 18/30
# Step 2/300Step 6/30Step 6/30Step 4/30Step 26/30Step 8/30Step 8/30Step 6/30Step 11/30Step 23/30Step 28/30Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 20/30Step 14/30
# Convergence (not necessarily to solution) at step 11/3030Step 14/30Step 11/30Step 16/30Step 26/30Step 1/30
# Convergence (not necessarily to solution) at step 13/30/30Step 9/30Step 19/30Step 0/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 12/30
# Step 10/30Convergence (not necessarily to solution) at step 9/30Convergence (not necessarily to solution) at step 16/30
# Step 4/30
# Step 7/300Step 13/30Step 10/30Step 1/30Step 28/30Step 13/30Convergence (not necessarily to solution) at step 9/30
# Step 4/300tep 1/30Step 28/30Step 8/30Step 16/30Step 9/30Step 17/30Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 27/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 17/30/30Step 19/30Step 0/30Step 1/30
# Convergence (not necessarily to solution) at step 22/309/30Step 14/30
# Step 25/30Step 16/30Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 13/300Step 2/30Step 8/30Step 2/30Step 15/30Step 4/30Step 5/30Step 6/30Step 9/30Step 18/30Step 26/30Step 12/30Step 8/30Step 13/30
# Convergence (not necessarily to solution) at step 9/307/30Step 2/30
# Step 0/300Step 29/30Step 8/30Step 3/30Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 10/30
# Step 4/300Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 18/30/30Step 2/30Step 12/30Step 6/30
# Convergence (not necessarily to solution) at step 10/3030Step 18/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 12/304/30Step 11/30Step 25/30Step 7/30Step 0/30Step 15/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 10/3030Step 7/30Step 19/30Step 3/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 9/30/30Step 7/30
# Convergence (not necessarily to solution) at step 20/30
# Step 0/300Step 8/30Step 27/30Step 3/30Step 12/30Step 13/30Step 3/30Step 4/30Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 9/3030Step 4/30Step 9/30Step 9/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 18/300Step 10/30Step 1/30Step 3/30Step 7/30
# Convergence (not necessarily to solution) at step 10/30/30Step 5/30Step 0/30Step 6/30Step 7/30Step 23/30Step 2/30Step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 11/30
# Step 10/30Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 10/3030Step 1/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 12/30
# Step 7/300Step 10/30Step 13/30Step 10/30Step 24/30Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 10/30/30Step 28/30Step 16/30Step 2/30Step 17/30Step 5/30Step 23/30Step 18/30Step 5/30
# Convergence (not necessarily to solution) at step 29/30
# Step 14/30Step 15/30Step 6/30Step 6/30Step 8/30Step 1/30Step 7/30Step 9/30Step 7/30Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 10/30
# Step 29/30Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30Step 3/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 12/30Step 9/30Step 13/30Step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 9/30
# Step 2/300Step 11/30Step 8/30Step 6/30Step 3/30Step 0/30Step 12/30Step 27/30Step 2/30Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/3030Step 6/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/300Step 6/30Step 25/30Step 9/30Step 20/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 10/3030Step 28/30Step 10/30Step 14/30Step 6/30Step 11/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 19/3030Step 10/30Step 7/30Step 26/30Step 18/30Step 15/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 11/30
# Step 10/30Step 19/30Convergence (not necessarily to solution) at step 16/30
# Step 2/300Step 7/30Step 20/30Step 4/30Step 9/30Step 0/30Convergence (not necessarily to solution) at step 12/30Step 24/30
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/301/30Step 1/30
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 12/30/30Step 10/30Step 24/30Step 8/30Step 14/30Step 28/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 15/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 22/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30Step 28/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 26/30
# Step 28/30Step 26/30Step 23/30Step 1/30Step 11/30Step 8/30Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 18/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 14/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 12/30
# Convergence (not necessarily to solution) at step 16/30
# Convergence (not necessarily to solution) at step 24/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 19/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 10/30
# Step 15/30Step 3/30Convergence (not necessarily to solution) at step 17/30
# Convergence (not necessarily to solution) at step 9/30
# Convergence (not necessarily to solution) at step 9/30Step 19/30
# Convergence (not necessarily to solution) at step 11/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 13/30
# Convergence (not necessarily to solution) at step 25/30
# Convergence (not necessarily to solution) at step 10/30
# Convergence (not necessarily to solution) at step 20/30
# Convergence (not necessarily to solution) at step 26/30
# Convergence (not necessarily to solution) at step 18/30
# Step 29/30
