# %% [markdown]
# ## Training with a ```Session``` object

# %%
import sys
from architecture.session import Session, egeofno_ver1, egeofno_ver2, \
    egeofno_ver3, egeofno_ver4, svdfno_ver1, svdfno_ver2, svdfno_ver3, svdfno_ver4

######### FIX MATRIX PLOTTING TAMALE #####
N_train = 20001
data_dir = "/home/emastr/deep-micro-slip-model/data/micro_geometries_boundcurv_repar_256_torch/data_1.torch"
save_dir = "/mnt/data0/emastr/article_training/"
dash_dir = "/home/emastr/deep-micro-slip-model/data/dashboard/"

# %%
save_name = "svdfno_ver4"
net = svdfno_ver4()
session = Session(net, save_name=save_name, path_data=data_dir, save_dir=save_dir, dash_dir=dash_dir)
session.train_nsteps(N_train)


save_name = "svdfno_ver3"
net = svdfno_ver3()
session = Session(net, save_name=save_name, path_data=data_dir, save_dir=save_dir, dash_dir=dash_dir)
session.train_nsteps(N_train)


save_name = "svdfno_ver1"
net = svdfno_ver1()
session = Session(net, save_name=save_name, path_data=data_dir, save_dir=save_dir, dash_dir=dash_dir)
session.train_nsteps(N_train)


save_name = "svdfno_ver2"
net = svdfno_ver2()
session = Session(net, save_name=save_name, path_data=data_dir, save_dir=save_dir, dash_dir=dash_dir)
session.train_nsteps(N_train)
# Out:
# ...
# Step 20000. Train loss = 1.96e-01, test loss = 2.28e-01, 40 iter/s, shape=256

# %%
save_name = "fno_ver1"
net = egeofno_ver1()
session = Session(net, save_name=save_name, path_data=data_dir, save_dir=save_dir, dash_dir=dash_dir)
session.train_nsteps(N_train)

save_name = "fno_ver2"
net = egeofno_ver2()
session = Session(net, save_name=save_name, path_data=data_dir, save_dir=save_dir, dash_dir=dash_dir)
session.train_nsteps(N_train)

save_name = "fno_ver3"
net = egeofno_ver3()
session = Session(net, save_name=save_name, path_data=data_dir, save_dir=save_dir, dash_dir=dash_dir)
session.train_nsteps(N_train)

save_name = "fno_ver4"
net = egeofno_ver4()
session = Session(net, save_name=save_name, path_data=data_dir, save_dir=save_dir, dash_dir=dash_dir)
session.train_nsteps(N_train)
# Out:
# ...
# Step 20000. Train loss = 3.30e-01, test loss = 3.36e-01, 108 iter/s, shape=256
