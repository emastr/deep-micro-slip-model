# %% [markdown]
# ## Rounded Micro Domain
#
# The micro domain is defined by a bounding box and a smooth function parameterising the floor of the micro domain.

# %%
import sys
sys.path.append('/home/emastr/phd/')

import torch
from boundary_solvers.gauss_grid_2d import *
from boundary_solvers.geometry import *
import numpy as np
import matplotlib.pyplot as plt
from util.plot_tools import *
from boundary_solvers.blobs import *

# %%
np.random.seed(0)
n = 3
plt.figure(figsize=(15,15))
riesz = []
zvec = []
for i in range(n * n):
    
    plt.subplot(n,n,i+1)
    mg = GPDomain("exp", 
                  shape=.05, 
                  num=20, 
                  scale=.05, 
                  bound=.3, 
                  width=1, 
                  height=1, 
                  corner_w = 0.3,
                  line_pos=0.6, 
                  n_refine=2, 
                  n_corner_refine=0)   
    
    mg.plot(ax=plt.gca())
    remove_axes(plt.gca())
    plt.axis("equal")


    
plt.figure(figsize=(10,10))
plt.subplot(2,2,4)
mg.plot(ax=plt.gca())
t,w = mg.grid.get_grid_and_weights()
ddz = np.zeros_like(t[:-1])
for der in range(3):
    dz = mg.eval_param(derivative=der)
    plt.subplot(2,2,der+1)
    plt.plot(t,np.imag(dz))
    plt.plot(t,np.real(dz))
    plt.plot(t[:-1],np.imag(ddz), 'r--')
    plt.plot(t[:-1],np.real(ddz), 'r--')
    ddz = (dz[1:]-dz[:-1])/(t[1:]-t[:-1])
# Out:
# Resample # 10

# %%
np.random.seed(0)
n = 2
plt.figure(figsize=(15,15))
plt.figure(figsize=(15,15))
riesz = []
zvec = []
for i in range(n * n):
    
    mg = GPDomain("exp", 
                  shape=.05, 
                  num=20, 
                  scale=.05, 
                  bound=.3, 
                  width=1, 
                  height=1, 
                  corner_w = 0.3,
                  line_pos=0.4, 
                  n_refine=2, 
                  n_corner_refine=0)    
    
    r1, func = mg.precompute_line_avg(derivative=0, tol=1e-10, maxiter=40, verbose=True)
    r2, _    = mg.precompute_line_avg(derivative=1, tol=1e-10, maxiter=40)
    r3, _    = mg.line_eval_adjoint(derivative=0, tol=1e-10, maxiter=40)
    mg.data["riesz_vec"]     = r1
    mg.data["riesz_vec_der"] = r2
    z = mg.eval_param()
    dz = mg.eval_param(derivative=1)
    a = mg.curve_length()
    
    # To test, plot field corresponding to riesz vector
    v = mg.zero_flow(r1)
    v /= np.linalg.norm(v)
    condition = lambda t: v
    problem = StokesDirichletProblem(mg, condition)
    problem.solve(tol=1e-9, maxiter=40)
    
    ### PLOT ###
    print(f"{i+1}/{n*n} done", end="\r")
   
    
    vel = lambda z: np.abs(problem.evaluate(z))
    #problem.geometry.plot_field(ax=plt.gca(), func=vel, apply_mask=True, cmap='inferno', vmax=np.max(np.abs(v)))
    #problem.geometry.plot_stream(ax=plt.gca(), func=problem.evaluate, apply_mask=True, color='white')
    #plt.quiver(np.real(z), np.imag(z), np.real(r1), np.imag(r1), color="red", scale=5)
    #mg.plot(ax=plt.gca(), show_samples=False, color="white", linewidth=3)  
    
    
    plt.figure(1)
    plt.subplot(n,n,i+1) 
    problem.geometry.plot_stream(ax=plt.gca(), func=problem.evaluate, apply_mask=True, color='black', linewidth=1)
    plt.quiver(np.real(z), np.imag(z), np.real(r1), np.imag(r1), color="black", scale=8)
    mg.plot(ax=plt.gca(), show_samples=False, color="black", linewidth=3)  
    
    plt.plot([-0.5,0.5], [0,0], "red")
    plt.plot([-0.5,0.5], [-0.6,-0.6], "red")
    
    #plt.xlim([-1,1])
    #plt.xlim([-1,1])
    plt.axis("equal")
    remove_axes(plt.gca())
    
    plt.figure(2)
    #plt.subplot(n,n,i+1) 
    plt.plot(a, np.real(r3), label="before adjoint inv")
    plt.plot(a, np.real(r1), '--', label="after adjoint inv")
    plt.legend()
    
    riesz.append(r1)
    zvec.append(z)
    
#plt.figure()
#for r in riesz:
#    plt.plot(np.imag(r))
# Out:
# Converged in 0 iterations
# Converged in 0 iterations
# Converged in 0 iterations
# Converged in 0 iterations
# 4/4 done

# %%
z_mean = np.zeros_like(zvec[0])
for z in zvec:
    z_mean += z / n**2

plt.plot(np.real(z_mean), np.imag(z_mean))
plt.axis("equal")
remove_axes(plt.gca())

# %% [markdown]
# ## Generating a data set

# %%
np.random.seed(0)
N = 2000
plt.figure(figsize=(15,15))
riesz = []
zvec = []
for i in range(N):
    print(f"{i+1}/{N} done", end="\n")
    mg = GPDomain("exp", 
                  shape=.05, 
                  num=20, 
                  scale=.05, 
                  bound=.3, 
                  width=1, 
                  height=1, 
                  corner_w = 0.3,
                  line_pos=np.random.rand()*0.4 + 0.2, 
                  n_refine=1, 
                  n_corner_refine=0)    
    
    r1, func = mg.precompute_line_avg(derivative=0, tol=1e-12, maxiter=200, verbose=True)
    r2, _    = mg.precompute_line_avg(derivative=1, tol=1e-12, maxiter=200, verbose=True)
    r3, _    = mg.line_eval_adjoint(derivative=0, tol=1e-12, maxiter=200, verbose=True)
    r4, _    = mg.line_eval_adjoint(derivative=1, tol=1e-12, maxiter=200, verbose=True)
    
    
    c = 1j + 1
    vec = np.conjugate(mg.eval_param()) - c
    a = mg.line_pos * 1j - 0.45 * mg.width - c
    b = mg.line_pos * 1j + 0.45 * mg.width - c
    print(f"numerical: {func(vec)}, true: {np.real(b**2 - a**2)/2}")
    
    mg.data["riesz_vec"]     = r1
    mg.data["riesz_vec_der"] = r2
    mg.data["line_eval_adjoint"] = r3
    mg.data["line_eval_der_adjoint"] = r4
    
    #mg.plot(ax=plt.gca(), shownormals=True, showpts=True, npts=500)
    #mg.plot(ax=plt.gca(), npts=300)
    mg.save(f"/home/emastr/phd/data/rounded_micro_domains_w_riesz_vectors/domain_{i}.GPDomain")
    #data = torch.load(f"/home/emastr/phd/data/rounded_micro_domains_w_riesz_vectors/domain_{i}.GPDomain")
    #data.pop("riesz_vec")
    #data.pop("riesz_vec_der")
    #data.pop("line_eval_adjoint")
    #data.pop("line_eval_der_adjoint")
    #mg = GPDomain.load(f"/home/emastr/phd/data/rounded_micro_domains_w_riesz_vectors/domain_{i}.GPDomain")
    #mg.plot(ax=plt.gca(), npts=300, linestyle='--')
    #plt.axis("equal")
    #remove_axes(plt.gca())
    #plt.xlim([-1,1])
    #plt.ylim([-0.5,1.2])
    #remove_axes(plt.gca())
# Out:
# 1/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000313333173318, true: -0.9
# 2/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999994782681047, true: -0.9
# 3/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998402815546, true: -0.8999999999999999
# 4/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999442103604, true: -0.9
# 5/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999410312983, true: -0.9
# 6/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999347591428, true: -0.9
# 7/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999985554029096, true: -0.9
# 8/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000001329230867, true: -0.9
# 9/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999518115787597, true: -0.9
# 10/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000055440431198, true: -0.9
# 11/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999450112223, true: -0.9
# 12/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000139060724, true: -0.8999999999999999
# 13/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999227961112, true: -0.9
# 14/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999336244346, true: -0.9
# 15/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998550923471, true: -0.9
# 16/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000001090363673, true: -0.8999999999999999
# 17/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000002684602202, true: -0.9
# 18/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000179058511603, true: -0.8999999999999999
# 19/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000001128108932, true: -0.9
# 20/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000085822684775, true: -0.9
# 21/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999339798361, true: -0.9
# 22/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000037027055614, true: -0.8999999999999999
# 23/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999973643776538, true: -0.9
# 24/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000083208594116, true: -0.9
# 25/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999853811250876, true: -0.8999999999999999
# 26/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999787880164387, true: -0.9
# 27/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999883358318779, true: -0.9
# 28/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999571554953, true: -0.8999999999999999
# 29/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999902765324546, true: -0.9
# 30/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000202233788065, true: -0.9
# 31/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999969050474925, true: -0.9
# 32/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999308393885, true: -0.9
# 33/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999814267152, true: -0.9
# 34/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999193687255, true: -0.9
# 35/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000003834081056, true: -0.9
# 36/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999042148491, true: -0.8999999999999999
# 37/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999969704301469, true: -0.8999999999999999
# 38/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999790512543, true: -0.8999999999999999
# 39/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000006470584869, true: -0.8999999999999999
# 40/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900004686140789, true: -0.9
# 41/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000151986252771, true: -0.9
# 42/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999985128617148, true: -0.8999999999999999
# 43/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999919386690296, true: -0.9
# 44/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9001183248003869, true: -0.9
# 45/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000001468048091, true: -0.8999999999999999
# 46/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000001463809322, true: -0.8999999999999999
# 47/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999518126699, true: -0.8999999999999999
# 48/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999515710709, true: -0.8999999999999999
# 49/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999900356914182, true: -0.8999999999999999
# 50/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999946981966831, true: -0.8999999999999999
# 51/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900000806652592, true: -0.8999999999999999
# 52/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999328441992, true: -0.9
# 53/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999550100314, true: -0.8999999999999999
# 54/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999629349148, true: -0.9
# 55/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999524819091, true: -0.9
# 56/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999255078603, true: -0.8999999999999999
# 57/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000023161460572, true: -0.9
# 58/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998915697932, true: -0.9
# 59/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999841702366651, true: -0.9
# 60/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000014570331529, true: -0.9
# 61/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000002145142536, true: -0.9
# 62/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998884581928, true: -0.8999999999999999
# 63/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999921033368, true: -0.9
# 64/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999935422648, true: -0.9
# 65/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899947683882681, true: -0.9
# 66/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000078805483998, true: -0.8999999999999999
# 67/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999976321111666, true: -0.8999999999999999
# 68/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999952240977558, true: -0.8999999999999999
# 69/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000837311596721, true: -0.8999999999999999
# 70/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999949505173, true: -0.8999999999999999
# 71/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999653282865, true: -0.9
# 72/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000185291453646, true: -0.9
# 73/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000005153494786, true: -0.9
# 74/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999988669691462, true: -0.8999999999999999
# 75/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999139315595, true: -0.9
# 76/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999248958939, true: -0.9
# 77/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999997849622321, true: -0.9
# 78/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900016995832801, true: -0.8999999999999999
# 79/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999788684038, true: -0.9
# 80/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000005205275701, true: -0.9
# 81/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999953858902364, true: -0.9
# 82/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999986676509303, true: -0.9
# 83/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000026661462368, true: -0.9
# 84/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000005852678574, true: -0.9
# 85/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000537778279, true: -0.9
# 86/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899998647153553, true: -0.9
# 87/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999961061719062, true: -0.8999999999999999
# 88/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999960468170487, true: -0.9
# 89/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999224101654, true: -0.9
# 90/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999835114728842, true: -0.9
# 91/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000010311001946, true: -0.9
# 92/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999927453381906, true: -0.8999999999999999
# 93/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999399084335, true: -0.8999999999999999
# 94/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999236390936, true: -0.9
# 95/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000907653898, true: -0.9
# 96/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999972428536563, true: -0.8999999999999999
# 97/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.90000000953093, true: -0.9
# 98/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999985633784845, true: -0.9
# 99/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999969672314063, true: -0.9
# 100/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000021248545195, true: -0.8999999999999999
# 101/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999255681318, true: -0.9
# 102/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999157238525, true: -0.9
# 103/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999749974519, true: -0.9
# 104/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999058681071, true: -0.9
# 105/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9001820680185046, true: -0.9
# 106/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000102494346829, true: -0.9
# 107/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999446266543, true: -0.9
# 108/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999269646886, true: -0.8999999999999999
# 109/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999484812322, true: -0.9
# 110/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000005688910134, true: -0.9
# 111/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000006705363882, true: -0.9
# 112/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000525360844, true: -0.9
# 113/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999771326668236, true: -0.9
# 114/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000026889881864, true: -0.9
# 115/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999218839283, true: -0.9
# 116/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999962306504257, true: -0.9
# 117/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999979883402355, true: -0.9
# 118/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999983603613531, true: -0.9
# 119/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.90005673011084, true: -0.9
# 120/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999301717031, true: -0.9
# 121/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000067287307212, true: -0.8999999999999999
# 122/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999995122565109, true: -0.8999999999999999
# 123/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000001788261471, true: -0.8999999999999999
# 124/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999225891409, true: -0.8999999999999999
# 125/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999984867475568, true: -0.9
# 126/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000020332115438, true: -0.8999999999999999
# 127/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000004769396566, true: -0.9
# 128/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999993329589899, true: -0.9
# 129/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999540108501, true: -0.8999999999999999
# 130/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999367134368, true: -0.9
# 131/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000625905426154, true: -0.9
# 132/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999104955289, true: -0.8999999999999999
# 133/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000007935898037, true: -0.9
# 134/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000019054351203, true: -0.8999999999999999
# 135/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998132433226, true: -0.8999999999999999
# 136/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999523086937, true: -0.8999999999999999
# 137/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000007373811983, true: -0.8999999999999999
# 138/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000072513191766, true: -0.8999999999999999
# 139/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999953460539665, true: -0.8999999999999999
# 140/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000002383477999, true: -0.8999999999999999
# 141/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000731420617, true: -0.9
# 142/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000012911386233, true: -0.9
# 143/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000219798582418, true: -0.9
# 144/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900001962146947, true: -0.9
# 145/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999421145103, true: -0.9
# 146/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999952388468471, true: -0.9
# 147/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999993609903202, true: -0.9
# 148/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999453078651, true: -0.8999999999999999
# 149/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000008049489672, true: -0.8999999999999999
# 150/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000058328344456, true: -0.9
# 151/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999316839633, true: -0.9
# 152/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.89999955937113, true: -0.9
# 153/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000055485551, true: -0.9
# 154/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999534287603, true: -0.9
# 155/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000024987403009, true: -0.8999999999999999
# 156/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000005590759452, true: -0.9
# 157/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998706236529, true: -0.9
# 158/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000001643554172, true: -0.8999999999999999
# 159/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999525627831, true: -0.9
# 160/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900004959772196, true: -0.9
# 161/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999959542143375, true: -0.9
# 162/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999726508794716, true: -0.8999999999999999
# 163/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999509623479, true: -0.8999999999999999
# 164/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999891731646086, true: -0.9
# 165/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999330853231, true: -0.8999999999999999
# 166/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999447522193, true: -0.9
# 167/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999245950008, true: -0.9
# 168/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999318262868, true: -0.9
# 169/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000812624980468, true: -0.8999999999999999
# 170/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999996767576384, true: -0.9
# 171/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900000048515196, true: -0.8999999999999999
# 172/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999617950158, true: -0.9
# 173/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000028914198, true: -0.9
# 174/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000007974167299, true: -0.8999999999999999
# 175/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000082755539603, true: -0.9
# 176/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999393796281, true: -0.8999999999999999
# 177/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000095341145293, true: -0.8999999999999999
# 178/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000002745246399, true: -0.9
# 179/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000146352512846, true: -0.9
# 180/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900000009212049, true: -0.9
# 181/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000021005791831, true: -0.8999999999999999
# 182/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999982803956631, true: -0.9
# 183/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999457085548, true: -0.9
# 184/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899988222109179, true: -0.9
# 185/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900000403299495, true: -0.9
# 186/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999446401126, true: -0.8999999999999999
# 187/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999457723376, true: -0.8999999999999999
# 188/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998950359709, true: -0.9
# 189/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998896897259, true: -0.9
# 190/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999996301169206, true: -0.8999999999999999
# 191/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999443243544, true: -0.8999999999999999
# 192/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900003001787448, true: -0.8999999999999999
# 193/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000099886207, true: -0.9
# 194/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999996259790854, true: -0.9
# 195/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000034576396998, true: -0.9
# 196/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000002718086149, true: -0.9
# 197/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999154251404, true: -0.9
# 198/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999815413904, true: -0.9
# 199/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999987988283056, true: -0.8999999999999999
# 200/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000003860571684, true: -0.9
# 201/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999983944489317, true: -0.9
# 202/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000035006970983, true: -0.8999999999999999
# 203/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999293596619, true: -0.9
# 204/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000018907206966, true: -0.8999999999999999
# 205/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999100028211, true: -0.9
# 206/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900002349398177, true: -0.9
# 207/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999353322699, true: -0.9
# 208/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999529340578, true: -0.9
# 209/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999349246833, true: -0.9
# 210/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999262633753, true: -0.9
# 211/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999294691974, true: -0.9
# 212/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000009272968608, true: -0.9
# 213/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999901492933636, true: -0.8999999999999999
# 214/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999984037170494, true: -0.9
# 215/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999424176337, true: -0.9
# 216/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998010561924, true: -0.9
# 217/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999346475325, true: -0.9
# 218/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999783039063, true: -0.8999999999999999
# 219/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998773906052, true: -0.9
# 220/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999390439332418, true: -0.8999999999999999
# 221/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000107523339776, true: -0.8999999999999999
# 222/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999994453261546, true: -0.9
# 223/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900001864455776, true: -0.9
# 224/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999330612749, true: -0.8999999999999999
# 225/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8998841207133675, true: -0.9
# 226/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000008808268395, true: -0.8999999999999999
# 227/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000037258649087, true: -0.9
# 228/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999343741988, true: -0.9
# 229/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999308068678, true: -0.9
# 230/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999331222597, true: -0.8999999999999999
# 231/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999238260155, true: -0.8999999999999999
# 232/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998232292173, true: -0.9
# 233/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000009877018427, true: -0.9
# 234/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899998646554963, true: -0.8999999999999999
# 235/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000029638920075, true: -0.9
# 236/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999988091548085, true: -0.9
# 237/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999463341858, true: -0.9
# 238/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999731359136575, true: -0.8999999999999999
# 239/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000074499255295, true: -0.9
# 240/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999991687091143, true: -0.8999999999999999
# 241/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999940507768274, true: -0.9
# 242/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000190232447216, true: -0.9
# 243/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999363583789, true: -0.9
# 244/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000052110549455, true: -0.9
# 245/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999333140983, true: -0.8999999999999999
# 246/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999515974643, true: -0.8999999999999999
# 247/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000105805678578, true: -0.8999999999999999
# 248/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999342177013, true: -0.8999999999999999
# 249/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999102283384, true: -0.9
# 250/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999420245206, true: -0.9
# 251/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999897974963, true: -0.9
# 252/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000286871673235, true: -0.8999999999999999
# 253/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999022384119, true: -0.8999999999999999
# 254/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999512970617, true: -0.8999999999999999
# 255/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998429467622, true: -0.9
# 256/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999400404904, true: -0.9
# 257/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000001127685544, true: -0.9
# 258/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999958837246514, true: -0.9
# 259/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000512472022, true: -0.9
# 260/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999700450396, true: -0.8999999999999999
# 261/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999996129478769, true: -0.9
# 262/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999736314170746, true: -0.8999999999999999
# 263/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999615372476, true: -0.9
# 264/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900012791007504, true: -0.9
# 265/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999252759082, true: -0.9
# 266/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998424107666, true: -0.9
# 267/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999605101974, true: -0.9
# 268/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999991495168144, true: -0.8999999999999999
# 269/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999950038977649, true: -0.9
# 270/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999192071702, true: -0.9
# 271/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900033407332149, true: -0.9
# 272/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000012002707563, true: -0.8999999999999999
# 273/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000407382121698, true: -0.9
# 274/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999478883536, true: -0.8999999999999999
# 275/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000001177675002, true: -0.9
# 276/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000003242143708, true: -0.9
# 277/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999791746151672, true: -0.8999999999999999
# 278/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999495934398799, true: -0.9
# 279/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999931606094, true: -0.9
# 280/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999982560415397, true: -0.8999999999999999
# 281/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999308513409, true: -0.9
# 282/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999997746533098, true: -0.9
# 283/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999352323854, true: -0.8999999999999999
# 284/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000002885242409, true: -0.9
# 285/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999361683927, true: -0.9
# 286/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999283089481, true: -0.8999999999999999
# 287/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000007745856193, true: -0.9
# 288/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999226249847, true: -0.8999999999999999
# 289/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999866435798, true: -0.9
# 290/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999900254352, true: -0.9
# 291/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999987572510686, true: -0.8999999999999999
# 292/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000048561677993, true: -0.9
# 293/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000901099212453, true: -0.9
# 294/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999954498984, true: -0.9
# 295/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999451033032, true: -0.9
# 296/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999964154247682, true: -0.9
# 297/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998478741014, true: -0.9
# 298/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999265539629, true: -0.9
# 299/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900014567099475, true: -0.9
# 300/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999441717212, true: -0.9
# 301/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999514929069, true: -0.9
# 302/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000003376267851, true: -0.9
# 303/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998243637435, true: -0.9
# 304/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999947783694, true: -0.9
# 305/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000027105324518, true: -0.9
# 306/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999288640768, true: -0.9
# 307/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999332054378, true: -0.9
# 308/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999941546356, true: -0.8999999999999999
# 309/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900000436514281, true: -0.9
# 310/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999973449135299, true: -0.9
# 311/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999987512904133, true: -0.9
# 312/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999895043719, true: -0.8999999999999999
# 313/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999595628784, true: -0.8999999999999999
# 314/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999525151772, true: -0.9
# 315/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000004901846252, true: -0.9
# 316/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000380717964417, true: -0.9
# 317/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999989294812971, true: -0.8999999999999999
# 318/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999916945891, true: -0.8999999999999999
# 319/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999941948944644, true: -0.8999999999999999
# 320/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000151142512484, true: -0.9
# 321/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999359582177, true: -0.9
# 322/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000012538134637, true: -0.8999999999999999
# 323/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000227633884909, true: -0.9
# 324/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999466410118, true: -0.9
# 325/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999101380624, true: -0.9
# 326/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999216512591, true: -0.9
# 327/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999947382333, true: -0.9
# 328/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999542990532, true: -0.9
# 329/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999305677951, true: -0.9
# 330/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999295364921, true: -0.8999999999999999
# 331/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999984755904208, true: -0.8999999999999999
# 332/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000318855375954, true: -0.9
# 333/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999930283902, true: -0.9
# 334/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000078398316, true: -0.9
# 335/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999228530208, true: -0.8999999999999999
# 336/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999103111855, true: -0.9
# 337/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999333447729, true: -0.9
# 338/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998356205191, true: -0.9
# 339/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999952391806353, true: -0.9
# 340/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999536517707, true: -0.9
# 341/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000056507908265, true: -0.8999999999999999
# 342/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999386568241, true: -0.9
# 343/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000100225374174, true: -0.9
# 344/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999684523832, true: -0.9
# 345/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000942887043, true: -0.8999999999999999
# 346/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998925377082, true: -0.8999999999999999
# 347/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999540050782, true: -0.9
# 348/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000001607246203, true: -0.9
# 349/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999448673316, true: -0.8999999999999999
# 350/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999792878619, true: -0.8999999999999999
# 351/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999937836745, true: -0.9
# 352/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000034085963312, true: -0.9
# 353/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999214972110479, true: -0.9
# 354/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000014859760601, true: -0.9
# 355/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000006187599836, true: -0.9
# 356/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999020400249, true: -0.9
# 357/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999320678849, true: -0.9
# 358/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000063976226901, true: -0.9
# 359/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999835728479, true: -0.8999999999999999
# 360/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899983237206756, true: -0.9
# 361/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999230282512, true: -0.8999999999999999
# 362/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999932429036, true: -0.9
# 363/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999632922493, true: -0.9
# 364/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999996864495091, true: -0.9
# 365/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999666757154, true: -0.9
# 366/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8998614068998306, true: -0.9
# 367/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999318535601, true: -0.9
# 368/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000205822846596, true: -0.9
# 369/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999260710898, true: -0.8999999999999999
# 370/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9332754483922905, true: -0.9
# 371/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000035360837741, true: -0.8999999999999999
# 372/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999939650153, true: -0.9
# 373/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999623505046, true: -0.9
# 374/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999690112427, true: -0.9
# 375/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999694752833, true: -0.9
# 376/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999884915978499, true: -0.9
# 377/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900000479840506, true: -0.9
# 378/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999925019899, true: -0.9
# 379/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000002450052633, true: -0.9
# 380/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900002049580809, true: -0.9
# 381/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999124247747916, true: -0.9
# 382/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999897458681813, true: -0.8999999999999999
# 383/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900003201318858, true: -0.8999999999999999
# 384/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000452359185, true: -0.8999999999999999
# 385/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000044998501089, true: -0.9
# 386/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999840969434497, true: -0.9
# 387/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999299288594, true: -0.8999999999999999
# 388/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9001373792638188, true: -0.8999999999999999
# 389/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999570122398, true: -0.9
# 390/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999700590312, true: -0.8999999999999999
# 391/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999544167258, true: -0.9
# 392/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000130043601445, true: -0.9
# 393/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999942781068049, true: -0.8999999999999999
# 394/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999994184462041, true: -0.9
# 395/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.89999993610989, true: -0.8999999999999999
# 396/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999208322252, true: -0.8999999999999999
# 397/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999286207796, true: -0.8999999999999999
# 398/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000037628633, true: -0.9
# 399/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999993635276091, true: -0.8999999999999999
# 400/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999343725281, true: -0.9
# 401/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999974397628228, true: -0.9
# 402/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000015559796425, true: -0.9
# 403/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999134786193, true: -0.9
# 404/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999454621878, true: -0.9
# 405/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999986526535042, true: -0.8999999999999999
# 406/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998598097856, true: -0.8999999999999999
# 407/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000009517749, true: -0.9
# 408/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998719831149, true: -0.9
# 409/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999748937091, true: -0.8999999999999999
# 410/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000050911824725, true: -0.8999999999999999
# 411/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000005131160782, true: -0.9
# 412/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999720418973574, true: -0.8999999999999999
# 413/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999997828288036, true: -0.8999999999999999
# 414/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999852300303068, true: -0.8999999999999999
# 415/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999680382138, true: -0.9
# 416/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999259800883, true: -0.9
# 417/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999955165446, true: -0.8999999999999999
# 418/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999950147309, true: -0.8999999999999999
# 419/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999600025356, true: -0.9
# 420/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999484881428, true: -0.9
# 421/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900005455629779, true: -0.9
# 422/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999976360256, true: -0.9
# 423/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# ...
# Converged in 0 iterations
# numerical: -0.8999999819314634, true: -0.9
# 1863/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000138738841712, true: -0.9
# 1864/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999380955503, true: -0.9
# 1865/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000044972729722, true: -0.9
# 1866/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999203794696, true: -0.9
# 1867/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9002420469164687, true: -0.9
# 1868/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999634793335048, true: -0.9
# 1869/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999959184038124, true: -0.9
# 1870/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999170198603, true: -0.9
# 1871/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999949509178276, true: -0.8999999999999999
# 1872/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000017358842495, true: -0.8999999999999999
# 1873/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999203727265, true: -0.9
# 1874/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000907314369, true: -0.8999999999999999
# 1875/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000063725297637, true: -0.8999999999999999
# 1876/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000088431268, true: -0.8999999999999999
# 1877/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999461285959, true: -0.9
# 1878/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999022381131, true: -0.8999999999999999
# 1879/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999961337405, true: -0.9
# 1880/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999470740601, true: -0.9
# 1881/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999219326031, true: -0.9
# 1882/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998885627901, true: -0.8999999999999999
# 1883/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999462547027, true: -0.9
# 1884/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000002808016097, true: -0.9
# 1885/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999719274139796, true: -0.8999999999999999
# 1886/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998980789305, true: -0.8999999999999999
# 1887/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999687562746, true: -0.8999999999999999
# 1888/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998897960746, true: -0.9
# 1889/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900001876331237, true: -0.9
# 1890/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999996951300657, true: -0.9
# 1891/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8997845711108649, true: -0.9
# 1892/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000001387442541, true: -0.9
# 1893/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999320276011, true: -0.8999999999999999
# 1894/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900000180416858, true: -0.8999999999999999
# 1895/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999454806384, true: -0.8999999999999999
# 1896/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999939766957936, true: -0.9
# 1897/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999995744910008, true: -0.9
# 1898/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000008744851116, true: -0.9
# 1899/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999377770743, true: -0.9
# 1900/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000044317912311, true: -0.9
# 1901/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999178883098, true: -0.8999999999999999
# 1902/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000000226424, true: -0.8999999999999999
# 1903/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999393198059, true: -0.9
# 1904/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000362069352, true: -0.9
# 1905/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999421322684, true: -0.8999999999999999
# 1906/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999568555328, true: -0.9
# 1907/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999989857132683, true: -0.9
# 1908/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000027285150753, true: -0.8999999999999999
# 1909/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999992260184868, true: -0.9
# 1910/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999456513871, true: -0.9
# 1911/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999997298369147, true: -0.8999999999999999
# 1912/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999996635489206, true: -0.9
# 1913/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999932324053, true: -0.9
# 1914/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999291093592, true: -0.9
# 1915/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999357848596, true: -0.9
# 1916/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000217037961298, true: -0.9
# 1917/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000020916291716, true: -0.9
# 1918/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999919175770492, true: -0.8999999999999999
# 1919/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000001567388431, true: -0.8999999999999999
# 1920/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999232128639, true: -0.8999999999999999
# 1921/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999334332325, true: -0.9
# 1922/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000001554669537, true: -0.9
# 1923/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999671806267, true: -0.9
# 1924/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000003171756494, true: -0.8999999999999999
# 1925/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.89999909491237, true: -0.9
# 1926/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999305409963, true: -0.9
# 1927/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.89998576094714, true: -0.8999999999999999
# 1928/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000093391991077, true: -0.9
# 1929/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9003522670025536, true: -0.8999999999999999
# 1930/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999962876304446, true: -0.9
# 1931/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000072579519568, true: -0.9
# 1932/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999502234868, true: -0.8999999999999999
# 1933/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999088258135, true: -0.8999999999999999
# 1934/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999470354248, true: -0.8999999999999999
# 1935/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999992812224218, true: -0.9
# 1936/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999995706419207, true: -0.9
# 1937/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999997543827549, true: -0.9
# 1938/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000027181703084, true: -0.8999999999999999
# 1939/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999253503412, true: -0.8999999999999999
# 1940/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999291892271, true: -0.8999999999999999
# 1941/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899998600722203, true: -0.9
# 1942/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999549600852, true: -0.9
# 1943/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999371786526, true: -0.8999999999999999
# 1944/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999465568422, true: -0.9
# 1945/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000044085097205, true: -0.9
# 1946/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999356499713, true: -0.8999999999999999
# 1947/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998833238967, true: -0.9
# 1948/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999047941796, true: -0.8999999999999999
# 1949/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000010529827847, true: -0.9
# 1950/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8997843130812307, true: -0.9
# 1951/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999796433622, true: -0.9
# 1952/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999465243622, true: -0.9
# 1953/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999990883206691, true: -0.8999999999999999
# 1954/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999607777809, true: -0.8999999999999999
# 1955/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999807264076946, true: -0.8999999999999999
# 1956/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999965079220871, true: -0.9
# 1957/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000004736522298, true: -0.9
# 1958/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999971145826029, true: -0.9
# 1959/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899997449587264, true: -0.8999999999999999
# 1960/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999985384635754, true: -0.9
# 1961/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000014800159459, true: -0.9
# 1962/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999993114370284, true: -0.9
# 1963/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999441496039, true: -0.9
# 1964/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9002341918411926, true: -0.8999999999999999
# 1965/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999375225096, true: -0.9
# 1966/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000036768494895, true: -0.8999999999999999
# 1967/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000034573690174, true: -0.9
# 1968/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900001976265066, true: -0.8999999999999999
# 1969/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000832612484, true: -0.9
# 1970/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999979801154545, true: -0.8999999999999999
# 1971/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999408157431, true: -0.9
# 1972/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000006719537671, true: -0.9
# 1973/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999917720432284, true: -0.8999999999999999
# 1974/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999998569484984, true: -0.9
# 1975/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999296610364, true: -0.8999999999999999
# 1976/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000011506532742, true: -0.9
# 1977/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999996684209248, true: -0.9
# 1978/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999662777693, true: -0.9
# 1979/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899999970402576, true: -0.8999999999999999
# 1980/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999706244724086, true: -0.9
# 1981/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999994482254446, true: -0.8999999999999999
# 1982/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999838170774, true: -0.9
# 1983/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899955847011143, true: -0.9
# 1984/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999679126461, true: -0.9
# 1985/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000014787371672, true: -0.8999999999999999
# 1986/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999993246017444, true: -0.8999999999999999
# 1987/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000005400047828, true: -0.9
# 1988/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999248284198, true: -0.8999999999999999
# 1989/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900000671783021, true: -0.9
# 1990/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899936879842985, true: -0.9
# 1991/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999831065842769, true: -0.8999999999999999
# 1992/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999250218707, true: -0.9
# 1993/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000000132039229, true: -0.9
# 1994/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.900001267736862, true: -0.9
# 1995/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000471153657791, true: -0.9
# 1996/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000118911244054, true: -0.9
# 1997/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000003429590241, true: -0.9
# 1998/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.899953920482879, true: -0.9
# 1999/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.8999999334818737, true: -0.9
# 2000/2000 done
# Converged in 0 iterations
# Converged in 0 iterations
# numerical: -0.9000009902244755, true: -0.8999999999999999

# %% [markdown]
# # Convert to PyTorch Tensor

# %%
N = 2000
M = len(r1)

in_ch = ["zr", "zi", "dzr", "dzi", "ddzr", "ddzi", "line_eval_r", "line_eval_i", "w", "t"]
out_ch = ["riesz_r", "riesz_i"]

in_data = torch.zeros(N, len(in_ch), M)
out_data = torch.zeros(N, len(out_ch), M)

for i in range(N):
    print(f"{i+1}/{N} done", end="\r")
    data = torch.load(f"/home/emastr/phd/data/rounded_micro_domains_w_riesz_vectors/domain_{i}.GPDomain")
    riesz = data.pop("riesz_vec")
    line_eval = data.pop("line_eval_adjoint")
    data.pop("riesz_vec_der")
    data.pop("line_eval_der_adjoint")
    
    geom = GPDomain.load(data)
    t, w = geom.grid.get_grid_and_weights()
    z = geom.eval_param(derivative=0)
    dz = geom.eval_param(derivative=1)
    ddz = geom.eval_param(derivative=2)
    
    n = dz/np.abs(dz)
    r = np.imag(dz * np.conjugate(ddz))/np.abs(dz)**3 * n
    
    # Set in data
    in_data[i, 0, :] = torch.from_numpy(np.real(z))
    in_data[i, 1, :] = torch.from_numpy(np.imag(z))
    in_data[i, 2, :] = torch.from_numpy(np.real(dz))
    in_data[i, 3, :] = torch.from_numpy(np.imag(dz))
    in_data[i, 4, :] = torch.from_numpy(np.real(ddz))
    in_data[i, 5, :] = torch.from_numpy(np.imag(ddz))
    in_data[i, 6, :] = torch.from_numpy(np.real(line_eval))
    in_data[i, 7, :] = torch.from_numpy(np.imag(line_eval))
    in_data[i, 8, :] = torch.from_numpy(w)
    in_data[i, 9, :] = torch.from_numpy(t)
    
    # set out data
    out_data[i, 0, :] = torch.from_numpy(np.real(riesz))
    out_data[i, 1, :] = torch.from_numpy(np.imag(riesz))
    

# Save data to file
data = {"X": in_data, "Y": out_data, "info": {"in_ch": in_ch, "out_ch": out_ch}}
torch.save(data, "/home/emastr/phd/data/problem_data_riesz_TEST.torch")
# Out:
# 2000/2000 done

# %%
mg.grid.integrate(lambda t: np.ones_like(t)) / (2*np.pi)

t,_ = mg.grid.get_grid_and_weights()
dz = mg.eval_param(derivative=1)

print(mg.grid.integrate(lambda t: np.abs(mg.eval_param(derivative=1))))
print(np.sum(np.abs(dz)[:-1] * (t[1:]-t[:-1])))
# Out:
# 5.820757465097854
# 5.804797919424254

# %% [markdown]
# ## Independence to parameterisation
# We verify that the riesz representor is invariant to reparameterisation.

# %%
geom = GPDomain("exp", 
                  shape=.05, 
                  num=20, 
                  scale=.05, 
                  bound=.3, 
                  width=1, 
                  height=1, 
                  corner_w = 0.3,
                  line_pos=np.random.rand()*0.4 + 0.2, 
                  n_refine=2, 
                  n_corner_refine=0)    

z, dz, ddz = geom.param

t = lambda s: s  ** 2
dt = lambda s: 2 * s
ddt = lambda s: 2 * np.ones_like(s)

t_inv = lambda t: np.sqrt(t)
dom_s = t_inv(geom.grid.segments)

z_s = lambda s: z(t(s))
dz_s = lambda s: dt(s) * dz(t(s))
ddz_s = lambda s: ddt(s) * dz(t(s)) + (dt(s)**2) * ddz(t(s))

param = [z_s, dz_s, ddz_s]
grid = GaussLegGrid(segments=dom_s, corners=np.ones_like(dom_s).astype(int))
geom_s = Geometry(param, grid)

geom_s.plot(ax=plt.gca())
geom.plot(ax=plt.gca())

r1,_ = geom_s.line_eval_adjoint(-0.45*geom.width + 1j*geom.line_pos, 0.45*geom.width+1j*geom.line_pos, derivative=0)
a1 = geom_s.curve_length()

r2,_ = geom.line_eval_adjoint(derivative=0)
a2 = geom.curve_length()

plt.axis("equal")
remove_axes(plt.gca())

plt.figure()
plt.plot(a1, np.real(r1))
plt.plot(a2, np.real(r2), '--')
# Out:
# Resample # 1
